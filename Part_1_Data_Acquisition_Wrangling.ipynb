# %% [markdown]
# <a href="https://colab.research.google.com/github/knav25/Capstone-Final/blob/main/Part_1_Data_Acquisition_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Overview of Part I
#
# As we start our journey into Big Data Analytics, the first thing we need to do is **get the data** in the form we need for analysis!  We'll start with an overview of how to acquire and *wrangle* data.
#
# This notebook gives us a series of examples for:
#
# * Acquiring data from files and remote sources
# * Information extraction over HTML content
# * A basic "vocabulary" of operators over tables (the relational algebra)
#
# * "Data wrangling" or integration:
#   * Cleaning and filtering data, using rules and based operations
#   * Linking data across dataframes or relations
#   * The need for approximate match and record linking

# %% [markdown]
# ## The Motivating Question
# To illustrate the principles, we focus on the question of how old company CEOs and founders are.  The question was in part motivated by the following New York Times article:
#
# * Founders of Successful Tech Companies Are Mostly Middle-Aged: https://www.nytimes.com/2019/08/29/business/tech-start-up-founders-nest.html?searchResultPosition=2
#
# So let's test this hypothesis!

# %% [markdown]
# You should Restart the Session after this cell runs.  Then go ahead and run the pip install line for py_stringsimjoin.

# %%
# !pip3 install setuptools==72.2.0
# Out:
# Collecting setuptools==72.2.0
#   Downloading setuptools-72.2.0-py3-none-any.whl.metadata (6.6 kB)
# Downloading setuptools-72.2.0-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.4 MB/s eta 0:00:00
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed setuptools-72.2.0

# %%
# !pip3 install git+https://github.com/anhaidgroup/py_stringsimjoin.git@rel_0_3_6
# Out:
# Collecting git+https://github.com/anhaidgroup/py_stringsimjoin.git@rel_0_3_6
#   Cloning https://github.com/anhaidgroup/py_stringsimjoin.git (to revision rel_0_3_6) to /tmp/pip-req-build-wzu3v5ww
#   Running command git clone --filter=blob:none --quiet https://github.com/anhaidgroup/py_stringsimjoin.git /tmp/pip-req-build-wzu3v5ww
#   Running command git checkout -b rel_0_3_6 --track origin/rel_0_3_6
#   Switched to a new branch 'rel_0_3_6'
#   Branch 'rel_0_3_6' set up to track remote branch 'rel_0_3_6' from 'origin'.
#   Resolved https://github.com/anhaidgroup/py_stringsimjoin.git to commit d3ab2b31a8f9515e11bfa7abf9c33722cf6c9938
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from py-stringsimjoin==0.3.6) (1.4.2)
# Requirement already satisfied: pandas>=0.16.0 in /usr/local/lib/python3.11/dist-packages (from py-stringsimjoin==0.3.6) (2.2.2)
# Collecting PyPrind>=2.9.3 (from py-stringsimjoin==0.3.6)
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting py_stringmatching>=0.2.1 (from py-stringsimjoin==0.3.6)
#   Downloading py-stringmatching-0.4.6.tar.gz (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.6/849.6 kB 10.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from py-stringsimjoin==0.3.6) (1.17.0)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.0->py-stringsimjoin==0.3.6) (2024.2)
# Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Building wheels for collected packages: py-stringsimjoin, py_stringmatching
#   Building wheel for py-stringsimjoin (setup.py) ... done
#   Created wheel for py-stringsimjoin: filename=py_stringsimjoin-0.3.6-cp311-cp311-linux_x86_64.whl size=5512232 sha256=106745074cfdbabb651a7999d2efdc9b9a1e3b3cf6690064cae7c836c928292d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-iqop7md_/wheels/e9/84/27/835c03416251cb83f8eec033ba5adcbfa97949350338bd6240
#   Building wheel for py_stringmatching (setup.py) ... done
#   Created wheel for py_stringmatching: filename=py_stringmatching-0.4.6-cp311-cp311-linux_x86_64.whl size=2968284 sha256=cfe56c1bf60fcf2b30d82dde55fe7af2411b3644d3ce95d144836c4504b0445a
#   Stored in directory: /root/.cache/pip/wheels/b1/92/28/43ed7486c729852ca07eb30f0d894e62614fbd6b6b2f522687
# Successfully built py-stringsimjoin py_stringmatching
# Installing collected packages: PyPrind, py_stringmatching, py-stringsimjoin
# Successfully installed PyPrind-2.11.3 py-stringsimjoin-0.3.6 py_stringmatching-0.4.6

# %%
# Let's install some libraries useful for processing web data

# For string similarity
#!pip3 install py_stringsimjoin

# # lxml to parse xml tree
# !pip3 install lxml
# Out:
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (5.3.0)

# %%
# Imports we'll use through the notebook, collected here for simplicity

# For parsing dates and being able to compare
import datetime

# For fetching remote data
import urllib
import urllib.request

# Pandas dataframes and operations
import pandas as pd

# Numpy matrix and array operations
import numpy as np

# Sqlite is a simplistic database
import sqlite3

# Approximate string matching, see
import py_stringsimjoin as ssj
import py_stringmatching as sm

# Data visualization
import matplotlib

# %% [markdown]
# # Lecture Module 1: Acquiring Data
#
# To test our hypothesis, we might want:
#
# 1. A list of companies (and, for futher details, perhaps their lines of business)
# 2. A list of company CEOs
# 3. Ages of the CEOs
#
# We'll go through each of these using real data from the web.
#
# ### Reading Structured Data Sources
#
# Let's start by looking up data about companies.  An example of this is at:
#
# https://gist.githubusercontent.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv
#
# which has some nicely detailed information about companies, their categories, when they were founded, etc.  Let's load this (remote) CSV file into a dataframe.

# %%
data = urllib.request.urlopen(\
       'https://gist.github.com/jvilledieu/c3afe5bc21da28880a30/raw/a344034b82a11433ba6f149afa47e57567d4a18f/Companies.csv')

company_data_df = pd.read_csv(data)

# %%
# Let's write it to SQL, and read it back

conn = sqlite3.connect('local.db')

company_data_df.to_sql("companies", conn, if_exists="replace", index=False)

pd.read_sql_query('select * from companies', conn)
# Out:
#                                                 permalink  \
# 0                                   /organization/waywire
# 1                         /organization/tv-communications
# 2                           /organization/rock-your-paper
# 3                          /organization/in-touch-network
# 4                                   /organization/n-plusn
# ...                                                   ...
# 47753                                 /organization/zzish
# 47754  /organization/zznode-science-and-technology-co-ltd
# 47755                           /organization/zzzzapp-com
# 47756                          /organization/a-list-games
# 47757                                     /organization/x
#
#                                 name                   homepage_url  \
# 0                           #waywire         http://www.waywire.com
# 1                 &TV Communications          http://enjoyandtv.com
# 2                  'Rock' Your Paper   http://www.rockyourpaper.org
# 3                  (In)Touch Network  http://www.InTouchNetwork.com
# 4                         +n (PlusN)               http://plusn.com
# ...                              ...                            ...
# 47753                          Zzish           http://www.zzish.com
# 47754  ZZNode Science and Technology          http://www.zznode.com
# 47755          Zzzzapp Wireless ltd.         http://www.zzzzapp.com
# 47756                  [a]list games      http://www.alistgames.com
# 47757                          [x+1]       http://www.xplusone.com/
#
#                                                                          category_list  \
# 0                                           |Entertainment|Politics|Social Media|News|
# 1                                                                              |Games|
# 2                                                               |Publishing|Education|
# 3      |Electronics|Guides|Coffee|Restaurants|Music|iPhone|Apps|Mobile|iOS|E-Commerce|
# 4                                                                           |Software|
# ...                                                                                ...
# 47753                    |Analytics|Gamification|Developer APIs|iOS|Android|Education|
# 47754                                                            |Enterprise Software|
# 47755                                    |Web Development|Advertising|Wireless|Mobile|
# 47756                                                                          |Games|
# 47757                                                            |Enterprise Software|
#
#                       market funding_total_usd     status country_code  \
# 0                      News         1 750 000    acquired          USA
# 1                      Games        4 000 000   operating          USA
# 2                 Publishing           40 000   operating          EST
# 3                Electronics        1 500 000   operating          GBR
# 4                  Software         1 200 000   operating          USA
# ...                      ...               ...        ...          ...
# 47753             Education           320 000   operating          GBR
# 47754   Enterprise Software         1 587 301   operating          CHN
# 47755       Web Development            97 398   operating          HRV
# 47756                 Games         9 300 000   operating         None
# 47757   Enterprise Software        45 000 000   operating          USA
#
#       state_code         region         city  funding_rounds  founded_at  \
# 0             NY  New York City     New York               1  01/06/2012
# 1             CA    Los Angeles  Los Angeles               2        None
# 2           None        Tallinn      Tallinn               1  26/10/2012
# 3           None         London       London               1  01/04/2011
# 4             NY  New York City     New York               2  01/01/2012
# ...          ...            ...          ...             ...         ...
# 47753       None         London       London               1  28/01/2013
# 47754       None        Beijing      Beijing               1        None
# 47755       None          Split        Split               5  13/05/2012
# 47756       None           None         None               1        None
# 47757         NY  New York City     New York               4  01/01/1999
#
#       founded_month founded_quarter  founded_year first_funding_at  \
# 0           2012-06         2012-Q2        2012.0       30/06/2012
# 1              None            None           NaN       04/06/2010
# 2           2012-10         2012-Q4        2012.0       09/08/2012
# 3           2011-04         2011-Q2        2011.0       01/04/2011
# 4           2012-01         2012-Q1        2012.0       29/08/2012
# ...             ...             ...           ...              ...
# 47753       2013-01         2013-Q1        2013.0       24/03/2014
# 47754          None            None           NaN       01/04/2012
# 47755       2012-05         2012-Q2        2012.0       01/11/2011
# 47756          None            None           NaN       21/11/2011
# 47757       1999-01         1999-Q1        1999.0       01/06/2008
#
#       last_funding_at
# 0          30/06/2012
# 1          23/09/2010
# 2          09/08/2012
# 3          01/04/2011
# 4          04/09/2014
# ...               ...
# 47753      24/03/2014
# 47754      01/04/2012
# 47755      10/09/2014
# 47756      21/11/2011
# 47757      04/04/2013
#
# [47758 rows x 18 columns]

# %% [markdown]
# ## Companies' CEOs: a Web Table
#
# Now we need to figure out who the CEOs are for corporations.  One place to look is Wikipedia, which has an HTML table describing the CEOs.
#
# https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs
#
# Pandas actually makes it easy to read HTML tables...

# %%
# Now let's read an HTML table!

company_ceos_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_chief_executive_officers#List_of_CEOs')[1]

company_ceos_df
# Out:
#                 Company             Executive                           Title  \
# 0             Accenture           Julie Sweet                          CEO[1]
# 1    Aditya Birla Group  Kumar Mangalam Birla                     Chairman[2]
# 2         Adobe Systems      Shantanu Narayen  Chairman, president and CEO[3]
# 3                Airbus       Guillaume Faury                          CEO[4]
# 4               Alibaba              Eddie Wu             Director and CEO[5]
# ..                  ...                   ...                             ...
# 135     Warner Brothers           Ann Sarnoff         Chairwoman and CEO[123]
# 136         WarnerMedia           Jason Kilar                        CEO[124]
# 137         Wells Fargo        Charles Scharf          CEO and president[125]
# 138  Whole Foods Market           John Mackey                        CEO[126]
# 139        Zillow Group           Rich Barton                        CEO[127]
#
#        Since  \
# 0       2019
# 1    1995[2]
# 2       2007
# 3       2012
# 4    2023[6]
# ..       ...
# 135     2019
# 136     2020
# 137     2019
# 138     1980
# 139     2019
#
#                                                                                           Notes  \
# 0                                                               Succeeded Pierre Nanterme, died
# 1                                              Part of the Birla family business house in India
# 2                                                                           Formerly with Apple
# 3                                                                       Succeeded Louis Gallois
# 4                                                                                           NaN
# ..                                                                                          ...
# 135                  First woman to hold the position at the company; succeeded Kevin Tsujihara
# 136                                                             Previously with Hulu and Amazon
# 137                                                       Succeeded John Stumpf, previously COO
# 138                                                                                  Co-founder
# 139  Co-founder and previously was Zillow's CEO for nearly a decade. Succeeded Spencer Rascoff.
#
#         Updated
# 0    2019-01-31
# 1    2018-10-01
# 2    2018-10-01
# 3    2017-11-14
# 4    2024-07-19
# ..          ...
# 135  2019-10-10
# 136  2020-11-19
# 137         NaN
# 138  2017-11-11
# 139  2018-12-10
#
# [140 rows x 6 columns]

# %% [markdown]
# ## The Problem Gets Harder... Extracting Structured Fields
#
# So far we have companies and CEOs.  But we don't have information on how old the CEOs are!
#
# For a solution, we're going to go back to Wikipedia -- this time looking at the web pages for the CEOs!
#
# This involves "crawling" the CEO pages, and "scraping" the relevant content.  In other words we have to do *information extraction*.
#
# We'll start by constructing a list of CEO web pages, from the Company CEO dataframe above.  For this, we need to take the names and do a bit of tweaking, for example adding underscores instead of spaces.

# %%
crawl_list = []

for executive in company_ceos_df['Executive']:
  crawl_list.append('https://en.wikipedia.org/wiki/' + executive.replace(' ', '_'))

crawl_list
# Out:
# ['https://en.wikipedia.org/wiki/Julie_Sweet',
#  'https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla',
#  'https://en.wikipedia.org/wiki/Shantanu_Narayen',
#  'https://en.wikipedia.org/wiki/Guillaume_Faury',
#  'https://en.wikipedia.org/wiki/Eddie_Wu',
#  'https://en.wikipedia.org/wiki/Andy_Jassy',
#  'https://en.wikipedia.org/wiki/Lisa_Su',
#  'https://en.wikipedia.org/wiki/Stephen_Squeri',
#  'https://en.wikipedia.org/wiki/Joseph_R._Swedish',
#  'https://en.wikipedia.org/wiki/Tim_Cook',
#  'https://en.wikipedia.org/wiki/Aditya_Mittal',
#  'https://en.wikipedia.org/wiki/John_Stankey',
#  'https://en.wikipedia.org/wiki/Charles_Woodburn',
#  'https://en.wikipedia.org/wiki/Tapan_Singhel',
#  'https://en.wikipedia.org/wiki/Carlos_Torres_Vila',
#  'https://en.wikipedia.org/wiki/Brian_Moynihan',
#  'https://en.wikipedia.org/wiki/C.S._Venkatakrishnan',
#  'https://en.wikipedia.org/wiki/Warren_Buffett',
#  'https://en.wikipedia.org/wiki/Hubert_Joly',
#  'https://en.wikipedia.org/wiki/Sunil_Bharti_Mittal',
#  'https://en.wikipedia.org/wiki/Stephen_A._Schwarzman',
#  'https://en.wikipedia.org/wiki/Mike_Henry',
#  'https://en.wikipedia.org/wiki/Oliver_Zipse',
#  'https://en.wikipedia.org/wiki/Kelly_Ortberg',
#  'https://en.wikipedia.org/wiki/Rich_Lesser',
#  'https://en.wikipedia.org/wiki/Bob_Dudley',
#  'https://en.wikipedia.org/wiki/Hock_Tan',
#  'https://en.wikipedia.org/wiki/Denise_Morrison',
#  'https://en.wikipedia.org/wiki/Mark_Shuttleworth',
#  'https://en.wikipedia.org/wiki/Richard_Fairbank',
#  'https://en.wikipedia.org/wiki/Jim_Umpleby',
#  'https://en.wikipedia.org/wiki/Evan_Greenberg',
#  'https://en.wikipedia.org/wiki/Jane_N._Fraser',
#  'https://en.wikipedia.org/wiki/Chuck_Robbins',
#  'https://en.wikipedia.org/wiki/Jane_Fraser',
#  'https://en.wikipedia.org/wiki/James_Quincey',
#  'https://en.wikipedia.org/wiki/Brian_L._Roberts',
#  'https://en.wikipedia.org/wiki/Thomas_Gottstein',
#  'https://en.wikipedia.org/wiki/Ola_Källenius',
#  'https://en.wikipedia.org/wiki/Michael_Dell',
#  'https://en.wikipedia.org/wiki/Ed_Bastian',
#  'https://en.wikipedia.org/wiki/Christian_Sewing',
#  'https://en.wikipedia.org/wiki/Tobias_Meyer',
#  'https://en.wikipedia.org/wiki/Edward_D._Breen',
#  'https://en.wikipedia.org/wiki/Devin_Wenig',
#  'https://en.wikipedia.org/wiki/Börje_Ekholm',
#  'https://en.wikipedia.org/wiki/Darren_Woods',
#  'https://en.wikipedia.org/wiki/Carmine_Di_Sibio',
#  'https://en.wikipedia.org/wiki/Mark_Zuckerberg',
#  'https://en.wikipedia.org/wiki/Raj_Subramaniam',
#  'https://en.wikipedia.org/wiki/Sergio_Marchionne',
#  'https://en.wikipedia.org/wiki/Abigail_Johnson',
#  'https://en.wikipedia.org/wiki/James_Hackett',
#  'https://en.wikipedia.org/wiki/Terry_Gou',
#  'https://en.wikipedia.org/wiki/Lachlan_Murdoch',
#  'https://en.wikipedia.org/wiki/Ryan_Cohen',
#  'https://en.wikipedia.org/wiki/Phebe_Novakovic',
#  'https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.',
#  'https://en.wikipedia.org/wiki/Mary_T._Barra',
#  'https://en.wikipedia.org/wiki/Emma_Walmsley',
#  'https://en.wikipedia.org/wiki/David_M._Solomon',
#  'https://en.wikipedia.org/wiki/Sundar_Pichai',
#  'https://en.wikipedia.org/wiki/C_Vijayakumar',
#  'https://en.wikipedia.org/wiki/Antonio_Neri',
#  'https://en.wikipedia.org/wiki/Darius_Adamczyk',
#  'https://en.wikipedia.org/wiki/Noel_Quinn',
#  'https://en.wikipedia.org/wiki/Arvind_Krishna',
#  'https://en.wikipedia.org/wiki/Salil_Parekh',
#  'https://en.wikipedia.org/wiki/Pat_Gelsinger',
#  'https://en.wikipedia.org/wiki/James_Dimon',
#  'https://en.wikipedia.org/wiki/Pieter_Elbers',
#  'https://en.wikipedia.org/wiki/Charles_G._Koch',
#  'https://en.wikipedia.org/wiki/Marillyn_Hewson',
#  'https://en.wikipedia.org/wiki/Steve_Rowe',
#  'https://en.wikipedia.org/wiki/Chris_Kempczinski',
#  'https://en.wikipedia.org/wiki/Bob_Sternfels',
#  'https://en.wikipedia.org/wiki/Steven_A._Kandarian',
#  'https://en.wikipedia.org/wiki/Isaac_Larian',
#  'https://en.wikipedia.org/wiki/Satya_Nadella',
#  'https://en.wikipedia.org/wiki/James_P._Gorman',
#  'https://en.wikipedia.org/wiki/Jeff_Shell',
#  'https://en.wikipedia.org/wiki/Robert_James_Thomson',
#  'https://en.wikipedia.org/wiki/Mark_Thompson',
#  'https://en.wikipedia.org/wiki/Mark_Parker',
#  'https://en.wikipedia.org/wiki/Pekka_Lundmark',
#  'https://en.wikipedia.org/wiki/Vasant_Narasimhan',
#  'https://en.wikipedia.org/wiki/Tatsumi_Kimishima',
#  'https://en.wikipedia.org/wiki/Safra_Catz',
#  'https://en.wikipedia.org/wiki/Mark_Hurd',
#  'https://en.wikipedia.org/wiki/Ramon_Laguarta',
#  'https://en.wikipedia.org/wiki/Albert_Bourla',
#  'https://en.wikipedia.org/wiki/David_S._Taylor',
#  'https://en.wikipedia.org/wiki/John_Strangfeld',
#  'https://en.wikipedia.org/wiki/Alan_Joyce',
#  'https://en.wikipedia.org/wiki/Anil_Ambani',
#  'https://en.wikipedia.org/wiki/Mukesh_Ambani',
#  'https://en.wikipedia.org/wiki/Luca_de_Meo',
#  'https://en.wikipedia.org/wiki/David_I._McKay',
#  'https://en.wikipedia.org/wiki/Ross_McEwan',
#  'https://en.wikipedia.org/wiki/Ben_van_Beurden',
#  "https://en.wikipedia.org/wiki/Michael_O'Leary",
#  'https://en.wikipedia.org/wiki/Douglas_L._Peterson',
#  'https://en.wikipedia.org/wiki/Oh-Hyun_Kwon',
#  'https://en.wikipedia.org/wiki/Christian_Klein',
#  'https://en.wikipedia.org/wiki/Herbert_Fisk_Johnson_III',
#  'https://en.wikipedia.org/wiki/Jean-Pascal_Tricoire',
#  'https://en.wikipedia.org/wiki/Peter_Harrison',
#  'https://en.wikipedia.org/wiki/Chua_Sock_Koong',
#  'https://en.wikipedia.org/wiki/Masayoshi_Son',
#  'https://en.wikipedia.org/wiki/Tony_Aquila',
#  'https://en.wikipedia.org/wiki/Elon_Musk',
#  'https://en.wikipedia.org/wiki/Robert_E._Jordan',
#  'https://en.wikipedia.org/wiki/J._Clifford_Hudson',
#  'https://en.wikipedia.org/wiki/Brian_Niccol',
#  'https://en.wikipedia.org/wiki/Raymond_Kwok',
#  'https://en.wikipedia.org/wiki/William_H._Rogers_Jr.',
#  'https://en.wikipedia.org/wiki/Brian_Cornell',
#  'https://en.wikipedia.org/wiki/Rajesh_Gopinathan',
#  'https://en.wikipedia.org/wiki/Li_Dongsheng',
#  'https://en.wikipedia.org/wiki/Andy_Penn',
#  'https://en.wikipedia.org/wiki/Dave_Lewis',
#  'https://en.wikipedia.org/wiki/Elon_Musk',
#  'https://en.wikipedia.org/wiki/Alan_D._Schnitzer',
#  'https://en.wikipedia.org/wiki/Akio_Toyoda',
#  'https://en.wikipedia.org/wiki/Scott_Kirby',
#  'https://en.wikipedia.org/wiki/Brian_Thompson',
#  'https://en.wikipedia.org/wiki/Ralph_Hamers',
#  'https://en.wikipedia.org/wiki/Hans_Vestberg',
#  'https://en.wikipedia.org/wiki/Robert_Bakish',
#  'https://en.wikipedia.org/wiki/Ryan_McInerney',
#  'https://en.wikipedia.org/wiki/Vittorio_Colao',
#  'https://en.wikipedia.org/wiki/Herbert_Diess',
#  'https://en.wikipedia.org/wiki/Robert_Iger',
#  'https://en.wikipedia.org/wiki/Stefano_Pessina',
#  'https://en.wikipedia.org/wiki/Doug_McMillon',
#  'https://en.wikipedia.org/wiki/Ann_Sarnoff',
#  'https://en.wikipedia.org/wiki/Jason_Kilar',
#  'https://en.wikipedia.org/wiki/Charles_Scharf',
#  'https://en.wikipedia.org/wiki/John_Mackey',
#  'https://en.wikipedia.org/wiki/Rich_Barton']

# %%
# Use urllib.urlopen to crawl all pages in crawl_list, and store the response of the page
# in list pages

pages = []

for url in crawl_list:
    page = url.split("/")[-1] #extract the person name at the end of the url
    print('Looking at file %s' % page)

    # An issue: some of the accent characters won't work.  We need to convert them
    # into an HTML URL.  We'll split the URL, then use "parse.quote" to change
    # the structure, then re-form the URL
    url_list = list(urllib.parse.urlsplit(url))
    url_list[2] = urllib.parse.quote(url_list[2])
    url_ascii = urllib.parse.urlunsplit(url_list)
    try:
      response = urllib.request.urlopen((url_ascii))
      #Save page and url for later use.
      pages.append(response)
    except urllib.error.URLError as e:
      print(e.reason)
# Out:
# Looking at file Julie_Sweet
# Looking at file Kumar_Mangalam_Birla
# Looking at file Shantanu_Narayen
# Looking at file Guillaume_Faury
# Looking at file Eddie_Wu
# Looking at file Andy_Jassy
# Looking at file Lisa_Su
# Looking at file Stephen_Squeri
# Looking at file Joseph_R._Swedish
# Looking at file Tim_Cook
# Looking at file Aditya_Mittal
# Looking at file John_Stankey
# Looking at file Charles_Woodburn
# Looking at file Tapan_Singhel
# Looking at file Carlos_Torres_Vila
# Looking at file Brian_Moynihan
# Looking at file C.S._Venkatakrishnan
# Looking at file Warren_Buffett
# Looking at file Hubert_Joly
# Looking at file Sunil_Bharti_Mittal
# Looking at file Stephen_A._Schwarzman
# Looking at file Mike_Henry
# Looking at file Oliver_Zipse
# Looking at file Kelly_Ortberg
# Looking at file Rich_Lesser
# Looking at file Bob_Dudley
# Looking at file Hock_Tan
# Looking at file Denise_Morrison
# Looking at file Mark_Shuttleworth
# Looking at file Richard_Fairbank
# Looking at file Jim_Umpleby
# Looking at file Evan_Greenberg
# Looking at file Jane_N._Fraser
# Not Found
# Looking at file Chuck_Robbins
# Looking at file Jane_Fraser
# Looking at file James_Quincey
# Looking at file Brian_L._Roberts
# Looking at file Thomas_Gottstein
# Looking at file Ola_Källenius
# Looking at file Michael_Dell
# Looking at file Ed_Bastian
# Looking at file Christian_Sewing
# Looking at file Tobias_Meyer
# Looking at file Edward_D._Breen
# Looking at file Devin_Wenig
# Looking at file Börje_Ekholm
# Looking at file Darren_Woods
# Looking at file Carmine_Di_Sibio
# Looking at file Mark_Zuckerberg
# Looking at file Raj_Subramaniam
# Looking at file Sergio_Marchionne
# Looking at file Abigail_Johnson
# Looking at file James_Hackett
# Looking at file Terry_Gou
# Looking at file Lachlan_Murdoch
# Looking at file Ryan_Cohen
# Looking at file Phebe_Novakovic
# Looking at file H._Lawrence_Culp_Jr.
# Looking at file Mary_T._Barra
# Looking at file Emma_Walmsley
# Looking at file David_M._Solomon
# Looking at file Sundar_Pichai
# Looking at file C_Vijayakumar
# Looking at file Antonio_Neri
# Looking at file Darius_Adamczyk
# Looking at file Noel_Quinn
# Looking at file Arvind_Krishna
# Looking at file Salil_Parekh
# Looking at file Pat_Gelsinger
# Looking at file James_Dimon
# Looking at file Pieter_Elbers
# Looking at file Charles_G._Koch
# Looking at file Marillyn_Hewson
# Looking at file Steve_Rowe
# Looking at file Chris_Kempczinski
# Looking at file Bob_Sternfels
# Looking at file Steven_A._Kandarian
# Looking at file Isaac_Larian
# Looking at file Satya_Nadella
# Looking at file James_P._Gorman
# Looking at file Jeff_Shell
# Looking at file Robert_James_Thomson
# Looking at file Mark_Thompson
# Looking at file Mark_Parker
# Looking at file Pekka_Lundmark
# Looking at file Vasant_Narasimhan
# Looking at file Tatsumi_Kimishima
# Looking at file Safra_Catz
# Looking at file Mark_Hurd
# Looking at file Ramon_Laguarta
# Looking at file Albert_Bourla
# Looking at file David_S._Taylor
# Looking at file John_Strangfeld
# Looking at file Alan_Joyce
# Looking at file Anil_Ambani
# Looking at file Mukesh_Ambani
# Looking at file Luca_de_Meo
# Looking at file David_I._McKay
# Looking at file Ross_McEwan
# Looking at file Ben_van_Beurden
# Looking at file Michael_O'Leary
# Looking at file Douglas_L._Peterson
# Looking at file Oh-Hyun_Kwon
# Looking at file Christian_Klein
# Looking at file Herbert_Fisk_Johnson_III
# Looking at file Jean-Pascal_Tricoire
# Looking at file Peter_Harrison
# Looking at file Chua_Sock_Koong
# Looking at file Masayoshi_Son
# Looking at file Tony_Aquila
# Looking at file Elon_Musk
# Looking at file Robert_E._Jordan
# Looking at file J._Clifford_Hudson
# Looking at file Brian_Niccol
# Looking at file Raymond_Kwok
# Looking at file William_H._Rogers_Jr.
# Looking at file Brian_Cornell
# Looking at file Rajesh_Gopinathan
# Looking at file Li_Dongsheng
# Looking at file Andy_Penn
# Looking at file Dave_Lewis
# Looking at file Elon_Musk
# Looking at file Alan_D._Schnitzer
# Looking at file Akio_Toyoda
# Looking at file Scott_Kirby
# Looking at file Brian_Thompson
# Looking at file Ralph_Hamers
# Looking at file Hans_Vestberg
# Looking at file Robert_Bakish
# Looking at file Ryan_McInerney
# Looking at file Vittorio_Colao
# Looking at file Herbert_Diess
# Looking at file Robert_Iger
# Looking at file Stefano_Pessina
# Looking at file Doug_McMillon
# Looking at file Ann_Sarnoff
# Looking at file Jason_Kilar
# Looking at file Charles_Scharf
# Looking at file John_Mackey
# Looking at file Rich_Barton

# %% [markdown]
# ## Populating the Table with Executives

# %%
# Use lxml.etree.HTML(...) on the HTML content of each page to get a DOM tree that
# can be processed via XPath to extract the bday information.  Store the CEO name,
# webpage, and the birthdate (born) in exec_df.

# We first check that the HTML content has a table of type `vcard`,
# and then extract the `bday` information.  If there is no birthdate, the datetime
# value is NaT (not a type).

from lxml import etree

rows = []
for page in pages:
  url = page.geturl()
  print (url)
  content = page.read().decode("utf-8")
  tree = etree.HTML(content)  #create a DOM tree of the page
  bday = tree.xpath('//table[contains(@class,"vcard")]//span[@class="bday"]/text()')
  if len(bday) > 0:
      name = url[url.rfind('/')+1:] # The part of the URL after the last /
      rows.append({'name': name, 'page': url,
                  'born': datetime.datetime.strptime(bday[0], '%Y-%m-%d')})
  else:
          rows.append({'name': url[url.rfind('/')+1:], 'page': url
                                    , 'born': np.datetime64('NaT')})

exec_df = pd.DataFrame(rows)
exec_df
# Out:
# https://en.wikipedia.org/wiki/Julie_Sweet
# https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# https://en.wikipedia.org/wiki/Shantanu_Narayen
# https://en.wikipedia.org/wiki/Guillaume_Faury
# https://en.wikipedia.org/wiki/Eddie_Wu
# https://en.wikipedia.org/wiki/Andy_Jassy
# https://en.wikipedia.org/wiki/Lisa_Su
# https://en.wikipedia.org/wiki/Stephen_Squeri
# https://en.wikipedia.org/wiki/Joseph_R._Swedish
# https://en.wikipedia.org/wiki/Tim_Cook
# https://en.wikipedia.org/wiki/Aditya_Mittal
# https://en.wikipedia.org/wiki/John_Stankey
# https://en.wikipedia.org/wiki/Charles_Woodburn
# https://en.wikipedia.org/wiki/Tapan_Singhel
# https://en.wikipedia.org/wiki/Carlos_Torres_Vila
# https://en.wikipedia.org/wiki/Brian_Moynihan
# https://en.wikipedia.org/wiki/C.S._Venkatakrishnan
# https://en.wikipedia.org/wiki/Warren_Buffett
# https://en.wikipedia.org/wiki/Hubert_Joly
# https://en.wikipedia.org/wiki/Sunil_Bharti_Mittal
# https://en.wikipedia.org/wiki/Stephen_A._Schwarzman
# https://en.wikipedia.org/wiki/Mike_Henry
# https://en.wikipedia.org/wiki/Oliver_Zipse
# https://en.wikipedia.org/wiki/Kelly_Ortberg
# https://en.wikipedia.org/wiki/Rich_Lesser
# https://en.wikipedia.org/wiki/Bob_Dudley
# https://en.wikipedia.org/wiki/Hock_Tan
# https://en.wikipedia.org/wiki/Denise_Morrison
# https://en.wikipedia.org/wiki/Mark_Shuttleworth
# https://en.wikipedia.org/wiki/Richard_Fairbank
# https://en.wikipedia.org/wiki/Jim_Umpleby
# https://en.wikipedia.org/wiki/Evan_Greenberg
# https://en.wikipedia.org/wiki/Chuck_Robbins
# https://en.wikipedia.org/wiki/Jane_Fraser
# https://en.wikipedia.org/wiki/James_Quincey
# https://en.wikipedia.org/wiki/Brian_L._Roberts
# https://en.wikipedia.org/wiki/Thomas_Gottstein
# https://en.wikipedia.org/wiki/Ola_K%C3%A4llenius
# https://en.wikipedia.org/wiki/Michael_Dell
# https://en.wikipedia.org/wiki/Ed_Bastian
# https://en.wikipedia.org/wiki/Christian_Sewing
# https://en.wikipedia.org/wiki/Tobias_Meyer
# https://en.wikipedia.org/wiki/Edward_D._Breen
# https://en.wikipedia.org/wiki/Devin_Wenig
# https://en.wikipedia.org/wiki/B%C3%B6rje_Ekholm
# https://en.wikipedia.org/wiki/Darren_Woods
# https://en.wikipedia.org/wiki/Carmine_Di_Sibio
# https://en.wikipedia.org/wiki/Mark_Zuckerberg
# https://en.wikipedia.org/wiki/Raj_Subramaniam
# https://en.wikipedia.org/wiki/Sergio_Marchionne
# https://en.wikipedia.org/wiki/Abigail_Johnson
# https://en.wikipedia.org/wiki/James_Hackett
# https://en.wikipedia.org/wiki/Terry_Gou
# https://en.wikipedia.org/wiki/Lachlan_Murdoch
# https://en.wikipedia.org/wiki/Ryan_Cohen
# https://en.wikipedia.org/wiki/Phebe_Novakovic
# https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.
# https://en.wikipedia.org/wiki/Mary_T._Barra
# https://en.wikipedia.org/wiki/Emma_Walmsley
# https://en.wikipedia.org/wiki/David_M._Solomon
# https://en.wikipedia.org/wiki/Sundar_Pichai
# https://en.wikipedia.org/wiki/C_Vijayakumar
# https://en.wikipedia.org/wiki/Antonio_Neri
# https://en.wikipedia.org/wiki/Darius_Adamczyk
# https://en.wikipedia.org/wiki/Noel_Quinn
# https://en.wikipedia.org/wiki/Arvind_Krishna
# https://en.wikipedia.org/wiki/Salil_Parekh
# https://en.wikipedia.org/wiki/Pat_Gelsinger
# https://en.wikipedia.org/wiki/James_Dimon
# https://en.wikipedia.org/wiki/Pieter_Elbers
# https://en.wikipedia.org/wiki/Charles_G._Koch
# https://en.wikipedia.org/wiki/Marillyn_Hewson
# https://en.wikipedia.org/wiki/Steve_Rowe
# https://en.wikipedia.org/wiki/Chris_Kempczinski
# https://en.wikipedia.org/wiki/Bob_Sternfels
# https://en.wikipedia.org/wiki/Steven_A._Kandarian
# https://en.wikipedia.org/wiki/Isaac_Larian
# https://en.wikipedia.org/wiki/Satya_Nadella
# https://en.wikipedia.org/wiki/James_P._Gorman
# https://en.wikipedia.org/wiki/Jeff_Shell
# https://en.wikipedia.org/wiki/Robert_James_Thomson
# https://en.wikipedia.org/wiki/Mark_Thompson
# https://en.wikipedia.org/wiki/Mark_Parker
# https://en.wikipedia.org/wiki/Pekka_Lundmark
# https://en.wikipedia.org/wiki/Vasant_Narasimhan
# https://en.wikipedia.org/wiki/Tatsumi_Kimishima
# https://en.wikipedia.org/wiki/Safra_Catz
# https://en.wikipedia.org/wiki/Mark_Hurd
# https://en.wikipedia.org/wiki/Ramon_Laguarta
# https://en.wikipedia.org/wiki/Albert_Bourla
# https://en.wikipedia.org/wiki/David_S._Taylor
# https://en.wikipedia.org/wiki/John_Strangfeld
# https://en.wikipedia.org/wiki/Alan_Joyce
# https://en.wikipedia.org/wiki/Anil_Ambani
# https://en.wikipedia.org/wiki/Mukesh_Ambani
# https://en.wikipedia.org/wiki/Luca_de_Meo
# https://en.wikipedia.org/wiki/David_I._McKay
# https://en.wikipedia.org/wiki/Ross_McEwan
# https://en.wikipedia.org/wiki/Ben_van_Beurden
# https://en.wikipedia.org/wiki/Michael_O%27Leary
# https://en.wikipedia.org/wiki/Douglas_L._Peterson
# https://en.wikipedia.org/wiki/Oh-Hyun_Kwon
# https://en.wikipedia.org/wiki/Christian_Klein
# https://en.wikipedia.org/wiki/Herbert_Fisk_Johnson_III
# https://en.wikipedia.org/wiki/Jean-Pascal_Tricoire
# https://en.wikipedia.org/wiki/Peter_Harrison
# https://en.wikipedia.org/wiki/Chua_Sock_Koong
# https://en.wikipedia.org/wiki/Masayoshi_Son
# https://en.wikipedia.org/wiki/Tony_Aquila
# https://en.wikipedia.org/wiki/Elon_Musk
# https://en.wikipedia.org/wiki/Robert_E._Jordan
# https://en.wikipedia.org/wiki/J._Clifford_Hudson
# https://en.wikipedia.org/wiki/Brian_Niccol
# https://en.wikipedia.org/wiki/Raymond_Kwok
# https://en.wikipedia.org/wiki/William_H._Rogers_Jr.
# https://en.wikipedia.org/wiki/Brian_Cornell
# https://en.wikipedia.org/wiki/Rajesh_Gopinathan
# https://en.wikipedia.org/wiki/Li_Dongsheng
# https://en.wikipedia.org/wiki/Andy_Penn
# https://en.wikipedia.org/wiki/Dave_Lewis
# https://en.wikipedia.org/wiki/Elon_Musk
# https://en.wikipedia.org/wiki/Alan_D._Schnitzer
# https://en.wikipedia.org/wiki/Akio_Toyoda
# https://en.wikipedia.org/wiki/Scott_Kirby
# https://en.wikipedia.org/wiki/Brian_Thompson
# https://en.wikipedia.org/wiki/Ralph_Hamers
# https://en.wikipedia.org/wiki/Hans_Vestberg
# https://en.wikipedia.org/wiki/Robert_Bakish
# https://en.wikipedia.org/wiki/Ryan_McInerney
# https://en.wikipedia.org/wiki/Vittorio_Colao
# https://en.wikipedia.org/wiki/Herbert_Diess
# https://en.wikipedia.org/wiki/Robert_Iger
# https://en.wikipedia.org/wiki/Stefano_Pessina
# https://en.wikipedia.org/wiki/Doug_McMillon
# https://en.wikipedia.org/wiki/Ann_Sarnoff
# https://en.wikipedia.org/wiki/Jason_Kilar
# https://en.wikipedia.org/wiki/Charles_Scharf
# https://en.wikipedia.org/wiki/John_Mackey
# https://en.wikipedia.org/wiki/Rich_Barton
#                      name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu              https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                 ...
# 134           Ann_Sarnoff           https://en.wikipedia.org/wiki/Ann_Sarnoff
# 135           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 136        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
# 137           John_Mackey           https://en.wikipedia.org/wiki/John_Mackey
# 138           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1968-02-22 00:00:00
# 4                    NaT
# ..                   ...
# 134                  NaT
# 135  1971-04-26 00:00:00
# 136  1965-04-24 00:00:00
# 137                  NaT
# 138                  NaT
#
# [139 rows x 3 columns]

# %% [markdown]
# # Lecture Module 2: Data Transformation
#
# Looking at our data to clean via *projection*...
#
# Generally, we can extract one "narrower" table form another by using **double brackets**.

# %%
# Let's take a look at the data.  Here's a way of PROJECTING the exec_df dataframe into
# a smaller table

exec_df[['name', 'born']]
# Out:
#                      name                 born
# 0             Julie_Sweet                  NaT
# 1    Kumar_Mangalam_Birla  1967-06-14 00:00:00
# 2        Shantanu_Narayen  1963-05-27 00:00:00
# 3         Guillaume_Faury  1968-02-22 00:00:00
# 4                Eddie_Wu                  NaT
# ..                    ...                  ...
# 134           Ann_Sarnoff                  NaT
# 135           Jason_Kilar  1971-04-26 00:00:00
# 136        Charles_Scharf  1965-04-24 00:00:00
# 137           John_Mackey                  NaT
# 138           Rich_Barton                  NaT
#
# [139 rows x 2 columns]

# %%
# If I use single brackets, I can extract a single column as a Series.
exec_df['name']
# Out:
# 0               Julie_Sweet
# 1      Kumar_Mangalam_Birla
# 2          Shantanu_Narayen
# 3           Guillaume_Faury
# 4                  Eddie_Wu
#                ...
# 134             Ann_Sarnoff
# 135             Jason_Kilar
# 136          Charles_Scharf
# 137             John_Mackey
# 138             Rich_Barton
# Name: name, Length: 139, dtype: object

# %%
# Notice anything awry?

for person in exec_df['name']:
    print (person)
# Out:
# Julie_Sweet
# Kumar_Mangalam_Birla
# Shantanu_Narayen
# Guillaume_Faury
# Eddie_Wu
# Andy_Jassy
# Lisa_Su
# Stephen_Squeri
# Joseph_R._Swedish
# Tim_Cook
# Aditya_Mittal
# John_Stankey
# Charles_Woodburn
# Tapan_Singhel
# Carlos_Torres_Vila
# Brian_Moynihan
# C.S._Venkatakrishnan
# Warren_Buffett
# Hubert_Joly
# Sunil_Bharti_Mittal
# Stephen_A._Schwarzman
# Mike_Henry
# Oliver_Zipse
# Kelly_Ortberg
# Rich_Lesser
# Bob_Dudley
# Hock_Tan
# Denise_Morrison
# Mark_Shuttleworth
# Richard_Fairbank
# Jim_Umpleby
# Evan_Greenberg
# Chuck_Robbins
# Jane_Fraser
# James_Quincey
# Brian_L._Roberts
# Thomas_Gottstein
# Ola_K%C3%A4llenius
# Michael_Dell
# Ed_Bastian
# Christian_Sewing
# Tobias_Meyer
# Edward_D._Breen
# Devin_Wenig
# B%C3%B6rje_Ekholm
# Darren_Woods
# Carmine_Di_Sibio
# Mark_Zuckerberg
# Raj_Subramaniam
# Sergio_Marchionne
# Abigail_Johnson
# James_Hackett
# Terry_Gou
# Lachlan_Murdoch
# Ryan_Cohen
# Phebe_Novakovic
# H._Lawrence_Culp_Jr.
# Mary_T._Barra
# Emma_Walmsley
# David_M._Solomon
# Sundar_Pichai
# C_Vijayakumar
# Antonio_Neri
# Darius_Adamczyk
# Noel_Quinn
# Arvind_Krishna
# Salil_Parekh
# Pat_Gelsinger
# James_Dimon
# Pieter_Elbers
# Charles_G._Koch
# Marillyn_Hewson
# Steve_Rowe
# Chris_Kempczinski
# Bob_Sternfels
# Steven_A._Kandarian
# Isaac_Larian
# Satya_Nadella
# James_P._Gorman
# Jeff_Shell
# Robert_James_Thomson
# Mark_Thompson
# Mark_Parker
# Pekka_Lundmark
# Vasant_Narasimhan
# Tatsumi_Kimishima
# Safra_Catz
# Mark_Hurd
# Ramon_Laguarta
# Albert_Bourla
# David_S._Taylor
# John_Strangfeld
# Alan_Joyce
# Anil_Ambani
# Mukesh_Ambani
# Luca_de_Meo
# David_I._McKay
# Ross_McEwan
# Ben_van_Beurden
# Michael_O%27Leary
# Douglas_L._Peterson
# Oh-Hyun_Kwon
# Christian_Klein
# Herbert_Fisk_Johnson_III
# Jean-Pascal_Tricoire
# Peter_Harrison
# Chua_Sock_Koong
# Masayoshi_Son
# Tony_Aquila
# Elon_Musk
# Robert_E._Jordan
# J._Clifford_Hudson
# Brian_Niccol
# Raymond_Kwok
# William_H._Rogers_Jr.
# Brian_Cornell
# Rajesh_Gopinathan
# Li_Dongsheng
# Andy_Penn
# Dave_Lewis
# Elon_Musk
# Alan_D._Schnitzer
# Akio_Toyoda
# Scott_Kirby
# Brian_Thompson
# Ralph_Hamers
# Hans_Vestberg
# Robert_Bakish
# Ryan_McInerney
# Vittorio_Colao
# Herbert_Diess
# Robert_Iger
# Stefano_Pessina
# Doug_McMillon
# Ann_Sarnoff
# Jason_Kilar
# Charles_Scharf
# John_Mackey
# Rich_Barton

# %%
def to_space(x):
  return x.replace('_', ' ')

# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(to_space)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 134             Ann Sarnoff
# 135             Jason Kilar
# 136          Charles Scharf
# 137             John Mackey
# 138             Rich Barton
# Name: name, Length: 139, dtype: object

# %%
# Let's use *apply* to call a function over each element, returning a new Series
exec_df['name'].apply(lambda x: x.replace('_', ' '))
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 134             Ann Sarnoff
# 135             Jason Kilar
# 136          Charles Scharf
# 137             John Mackey
# 138             Rich Barton
# Name: name, Length: 139, dtype: object

# %%
# I can also use *apply* to call a function over the rows of a dataframe
exec_df.apply(lambda x: x['name'].replace('_', ' '), axis=1)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 134             Ann Sarnoff
# 135             Jason Kilar
# 136          Charles Scharf
# 137             John Mackey
# 138             Rich Barton
# Length: 139, dtype: object

# %%
# Let's clean the name by removing underscores...
exec_df['clean_name'] = exec_df['name'].apply(lambda x: x.replace('_', ' '))

exec_df
# Out:
#                      name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu              https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                 ...
# 134           Ann_Sarnoff           https://en.wikipedia.org/wiki/Ann_Sarnoff
# 135           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 136        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
# 137           John_Mackey           https://en.wikipedia.org/wiki/John_Mackey
# 138           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 4                    NaT              Eddie Wu
# ..                   ...                   ...
# 134                  NaT           Ann Sarnoff
# 135  1971-04-26 00:00:00           Jason Kilar
# 136  1965-04-24 00:00:00        Charles Scharf
# 137                  NaT           John Mackey
# 138                  NaT           Rich Barton
#
# [139 rows x 4 columns]

# %%
exec_df.rename(columns={'name': 'old_name'})
# Out:
#                  old_name                                                page  \
# 0             Julie_Sweet           https://en.wikipedia.org/wiki/Julie_Sweet
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                Eddie_Wu              https://en.wikipedia.org/wiki/Eddie_Wu
# ..                    ...                                                 ...
# 134           Ann_Sarnoff           https://en.wikipedia.org/wiki/Ann_Sarnoff
# 135           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 136        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
# 137           John_Mackey           https://en.wikipedia.org/wiki/John_Mackey
# 138           Rich_Barton           https://en.wikipedia.org/wiki/Rich_Barton
#
#                     born            clean_name
# 0                    NaT           Julie Sweet
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 4                    NaT              Eddie Wu
# ..                   ...                   ...
# 134                  NaT           Ann Sarnoff
# 135  1971-04-26 00:00:00           Jason Kilar
# 136  1965-04-24 00:00:00        Charles Scharf
# 137                  NaT           John Mackey
# 138                  NaT           Rich Barton
#
# [139 rows x 4 columns]

# %%
# We can do the same via SQL.  For the example we'll save the dataframe first...  we'll convert
# types to string first to avoid errors.

temp_df= exec_df.applymap(str)
temp_df.to_sql('temp_exec', conn, if_exists="replace")

pd.read_sql_query('select name, replace(name, "_", " ") as clean_name from temp_exec', conn)
# Out:
# <ipython-input-18-a2ee51b046e2>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   temp_df= exec_df.applymap(str)
#                      name            clean_name
# 0             Julie_Sweet           Julie Sweet
# 1    Kumar_Mangalam_Birla  Kumar Mangalam Birla
# 2        Shantanu_Narayen      Shantanu Narayen
# 3         Guillaume_Faury       Guillaume Faury
# 4                Eddie_Wu              Eddie Wu
# ..                    ...                   ...
# 134           Ann_Sarnoff           Ann Sarnoff
# 135           Jason_Kilar           Jason Kilar
# 136        Charles_Scharf        Charles Scharf
# 137           John_Mackey           John Mackey
# 138           Rich_Barton           Rich Barton
#
# [139 rows x 2 columns]

# %% [markdown]
# ## Selecting a subset of the rows

# %%
# Here's a column

exec_df['clean_name']
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 134             Ann Sarnoff
# 135             Jason Kilar
# 136          Charles Scharf
# 137             John Mackey
# 138             Rich Barton
# Name: clean_name, Length: 139, dtype: object

# %%
# We can apply a test (predicate) to each column, returning a Series of boolean true/false values

exec_df['clean_name'] == 'Julie Sweet'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 134    False
# 135    False
# 136    False
# 137    False
# 138    False
# Name: clean_name, Length: 139, dtype: bool

# %%
# If we compose these, we'll get only those rows where the boolean condition was True

exec_df[exec_df['clean_name'] == 'Julie Sweet']
# Out:
#           name                                       page born   clean_name
# 0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT  Julie Sweet

# %%
exec_df[exec_df['clean_name'] == 'Julie Sweet'][['page']]
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %%
# And in SQL...

temp_df= exec_df.applymap(str)
temp_df.to_sql('temp_exec', conn, if_exists="replace")

pd.read_sql_query('select * from temp_exec where clean_name="Julie Sweet"', conn)
# Out:
# <ipython-input-23-5d71829a6c1c>:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   temp_df= exec_df.applymap(str)
#    index         name                                       page born  \
# 0      0  Julie_Sweet  https://en.wikipedia.org/wiki/Julie_Sweet  NaT
#
#     clean_name
# 0  Julie Sweet

# %%
pd.read_sql_query('select page from temp_exec where clean_name="Julie Sweet"', conn)
# Out:
#                                         page
# 0  https://en.wikipedia.org/wiki/Julie_Sweet

# %%
import numpy as np

exec_df.dropna(subset=['born'])
# Out:
#                      name                                                page  \
# 1    Kumar_Mangalam_Birla  https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2        Shantanu_Narayen      https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3         Guillaume_Faury       https://en.wikipedia.org/wiki/Guillaume_Faury
# 5              Andy_Jassy            https://en.wikipedia.org/wiki/Andy_Jassy
# 8       Joseph_R._Swedish     https://en.wikipedia.org/wiki/Joseph_R._Swedish
# ..                    ...                                                 ...
# 131           Robert_Iger           https://en.wikipedia.org/wiki/Robert_Iger
# 132       Stefano_Pessina       https://en.wikipedia.org/wiki/Stefano_Pessina
# 133         Doug_McMillon         https://en.wikipedia.org/wiki/Doug_McMillon
# 135           Jason_Kilar           https://en.wikipedia.org/wiki/Jason_Kilar
# 136        Charles_Scharf        https://en.wikipedia.org/wiki/Charles_Scharf
#
#                     born            clean_name
# 1    1967-06-14 00:00:00  Kumar Mangalam Birla
# 2    1963-05-27 00:00:00      Shantanu Narayen
# 3    1968-02-22 00:00:00       Guillaume Faury
# 5    1968-01-13 00:00:00            Andy Jassy
# 8    1951-05-17 00:00:00     Joseph R. Swedish
# ..                   ...                   ...
# 131  1951-02-10 00:00:00           Robert Iger
# 132  1941-06-04 00:00:00       Stefano Pessina
# 133  1966-10-17 00:00:00         Doug McMillon
# 135  1971-04-26 00:00:00           Jason Kilar
# 136  1965-04-24 00:00:00        Charles Scharf
#
# [78 rows x 4 columns]

# %%
pd.read_sql_query('select * from temp_exec where born is not null', conn).set_index('index')
# Out:
#                        name  \
# index
# 0               Julie_Sweet
# 1      Kumar_Mangalam_Birla
# 2          Shantanu_Narayen
# 3           Guillaume_Faury
# 4                  Eddie_Wu
# ...                     ...
# 134             Ann_Sarnoff
# 135             Jason_Kilar
# 136          Charles_Scharf
# 137             John_Mackey
# 138             Rich_Barton
#
#                                                      page  \
# index
# 0               https://en.wikipedia.org/wiki/Julie_Sweet
# 1      https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla
# 2          https://en.wikipedia.org/wiki/Shantanu_Narayen
# 3           https://en.wikipedia.org/wiki/Guillaume_Faury
# 4                  https://en.wikipedia.org/wiki/Eddie_Wu
# ...                                                   ...
# 134             https://en.wikipedia.org/wiki/Ann_Sarnoff
# 135             https://en.wikipedia.org/wiki/Jason_Kilar
# 136          https://en.wikipedia.org/wiki/Charles_Scharf
# 137             https://en.wikipedia.org/wiki/John_Mackey
# 138             https://en.wikipedia.org/wiki/Rich_Barton
#
#                       born            clean_name
# index
# 0                      NaT           Julie Sweet
# 1      1967-06-14 00:00:00  Kumar Mangalam Birla
# 2      1963-05-27 00:00:00      Shantanu Narayen
# 3      1968-02-22 00:00:00       Guillaume Faury
# 4                      NaT              Eddie Wu
# ...                    ...                   ...
# 134                    NaT           Ann Sarnoff
# 135    1971-04-26 00:00:00           Jason Kilar
# 136    1965-04-24 00:00:00        Charles Scharf
# 137                    NaT           John Mackey
# 138                    NaT           Rich Barton
#
# [139 rows x 4 columns]

# %% [markdown]
# ## Joining Data
#
# We start with a simple join between company_ceos_df and exec_df and persist it to the database.  We then check how many companies did not have a match on CEO name.

# %%
exec_df[['clean_name', 'born']]
# Out:
#                clean_name                 born
# 0             Julie Sweet                  NaT
# 1    Kumar Mangalam Birla  1967-06-14 00:00:00
# 2        Shantanu Narayen  1963-05-27 00:00:00
# 3         Guillaume Faury  1968-02-22 00:00:00
# 4                Eddie Wu                  NaT
# ..                    ...                  ...
# 134           Ann Sarnoff                  NaT
# 135           Jason Kilar  1971-04-26 00:00:00
# 136        Charles Scharf  1965-04-24 00:00:00
# 137           John Mackey                  NaT
# 138           Rich Barton                  NaT
#
# [139 rows x 2 columns]

# %%
# Remove any duplicate executive entries

exec_df = exec_df.drop_duplicates()

# %%
company_ceos_df[['Executive', 'Company']]
# Out:
#                 Executive             Company
# 0             Julie Sweet           Accenture
# 1    Kumar Mangalam Birla  Aditya Birla Group
# 2        Shantanu Narayen       Adobe Systems
# 3         Guillaume Faury              Airbus
# 4                Eddie Wu             Alibaba
# ..                    ...                 ...
# 135           Ann Sarnoff     Warner Brothers
# 136           Jason Kilar         WarnerMedia
# 137        Charles Scharf         Wells Fargo
# 138           John Mackey  Whole Foods Market
# 139           Rich Barton        Zillow Group
#
# [140 rows x 2 columns]

# %%
company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'])
# Out:
#                 Executive             Company            clean_name  \
# 0             Julie Sweet           Accenture           Julie Sweet
# 1    Kumar Mangalam Birla  Aditya Birla Group  Kumar Mangalam Birla
# 2        Shantanu Narayen       Adobe Systems      Shantanu Narayen
# 3         Guillaume Faury              Airbus       Guillaume Faury
# 4                Eddie Wu             Alibaba              Eddie Wu
# ..                    ...                 ...                   ...
# 131           Ann Sarnoff     Warner Brothers           Ann Sarnoff
# 132           Jason Kilar         WarnerMedia           Jason Kilar
# 133        Charles Scharf         Wells Fargo        Charles Scharf
# 134           John Mackey  Whole Foods Market           John Mackey
# 135           Rich Barton        Zillow Group           Rich Barton
#
#                     born
# 0                    NaT
# 1    1967-06-14 00:00:00
# 2    1963-05-27 00:00:00
# 3    1968-02-22 00:00:00
# 4                    NaT
# ..                   ...
# 131                  NaT
# 132  1971-04-26 00:00:00
# 133  1965-04-24 00:00:00
# 134                  NaT
# 135                  NaT
#
# [136 rows x 4 columns]

# %%
temp_df= company_ceos_df.applymap(str)
temp_df.to_sql('company_ceos', conn, if_exists="replace")
temp_df= exec_df.applymap(str)
temp_df.to_sql('executives', conn, if_exists="replace")
company_data_df.to_sql('company_data', conn, if_exists='replace')

pd.read_sql_query('select Executive, Company, born from company_ceos ' +\
                  'join executives on Executive=clean_name ' +\
                  'where born is not null', conn)
# Out:
# <ipython-input-31-b65b08d10c5a>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   temp_df= company_ceos_df.applymap(str)
# <ipython-input-31-b65b08d10c5a>:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   temp_df= exec_df.applymap(str)
#                 Executive             Company                 born
# 0             Julie Sweet           Accenture                  NaT
# 1    Kumar Mangalam Birla  Aditya Birla Group  1967-06-14 00:00:00
# 2        Shantanu Narayen       Adobe Systems  1963-05-27 00:00:00
# 3         Guillaume Faury              Airbus  1968-02-22 00:00:00
# 4                Eddie Wu             Alibaba                  NaT
# ..                    ...                 ...                  ...
# 131           Ann Sarnoff     Warner Brothers                  NaT
# 132           Jason Kilar         WarnerMedia  1971-04-26 00:00:00
# 133        Charles Scharf         Wells Fargo  1965-04-24 00:00:00
# 134           John Mackey  Whole Foods Market                  NaT
# 135           Rich Barton        Zillow Group                  NaT
#
# [136 rows x 3 columns]

# %% [markdown]
# ###Finding the misses in the join.
#
# Note that the join above resulted in 174 rows.  However, there are more rows in company_ceos_df so we are missing some companies.  We can see which are missed using a left outer join; setting "indicator= True" allows us to see which tuples in company_ceos_df failed to find a match (left_only, e.g. row 24 and 172).

# %%
pd.set_option('display.max_rows', 200)
display(company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="left", indicator=True))
# Out:
#                     Executive                          Company  \
# 0                 Julie Sweet                        Accenture
# 1        Kumar Mangalam Birla               Aditya Birla Group
# 2            Shantanu Narayen                    Adobe Systems
# 3             Guillaume Faury                           Airbus
# 4                    Eddie Wu                          Alibaba
# 5                  Andy Jassy                           Amazon
# 6                     Lisa Su           Advanced Micro Devices
# 7              Stephen Squeri                 American Express
# 8           Joseph R. Swedish                           Anthem
# 9                    Tim Cook                            Apple
# 10              Aditya Mittal                   Arcelor Mittal
# 11               John Stankey                             AT&T
# 12           Charles Woodburn                      BAE Systems
# 13              Tapan Singhel  Bajaj Allianz General Insurance
# 14         Carlos Torres Vila  Banco Bilbao Vizcaya Argentaria
# 15             Brian Moynihan                  Bank of America
# 16       C.S. Venkatakrishnan                         Barclays
# 17             Warren Buffett               Berkshire Hathaway
# 18                Hubert Joly                         Best Buy
# 19        Sunil Bharti Mittal               Bharti Enterprises
# 20      Stephen A. Schwarzman                 Blackstone Group
# 21                 Mike Henry                              BHP
# 22               Oliver Zipse                              BMW
# 23              Kelly Ortberg                           Boeing
# 24                Rich Lesser          Boston Consulting Group
# 25                 Bob Dudley                               BP
# 26                   Hock Tan                         Broadcom
# 27            Denise Morrison            Campbell Soup Company
# 28          Mark Shuttleworth                        Canonical
# 29           Richard Fairbank            Capital One Financial
# 30                Jim Umpleby                      Caterpillar
# 31             Evan Greenberg                            Chubb
# 32             Jane N. Fraser                        Citigroup
# 33              Chuck Robbins                    Cisco Systems
# 34                Jane Fraser                        Citigroup
# 35              James Quincey                        Coca-Cola
# 36           Brian L. Roberts                          Comcast
# 37           Thomas Gottstein                    Credit Suisse
# 38              Ola Källenius                       Daimler AG
# 39               Michael Dell                             Dell
# 40                 Ed Bastian                  Delta Air Lines
# 41           Christian Sewing                    Deutsche Bank
# 42               Tobias Meyer                        DHL Group
# 43            Edward D. Breen             Dow Chemical Company
# 44                Devin Wenig                             eBay
# 45               Börje Ekholm                         Ericsson
# 46               Darren Woods                       ExxonMobil
# 47           Carmine Di Sibio                    Ernst & Young
# 48            Mark Zuckerberg                         Facebook
# 49            Raj Subramaniam                            FedEx
# 50          Sergio Marchionne                             Fiat
# 51            Abigail Johnson             Fidelity Investments
# 52              James Hackett                             Ford
# 53                  Terry Gou                          Foxconn
# 54            Lachlan Murdoch                  Fox Corporation
# 55                 Ryan Cohen                         GameStop
# 56            Phebe Novakovic                 General Dynamics
# 57       H. Lawrence Culp Jr.                 General Electric
# 58              Mary T. Barra                   General Motors
# 59              Emma Walmsley                  GlaxoSmithKline
# 60           David M. Solomon                    Goldman Sachs
# 61              Sundar Pichai                           Google
# 62              C Vijayakumar                 HCL Technologies
# 63               Antonio Neri       Hewlett Packard Enterprise
# 64            Darius Adamczyk                        Honeywell
# 65                 Noel Quinn                             HSBC
# 66             Arvind Krishna                              IBM
# 67               Salil Parekh                          Infosys
# 68              Pat Gelsinger                            Intel
# 69                James Dimon                  JP Morgan Chase
# 70              Pieter Elbers                              KLM
# 71            Charles G. Koch                  Koch Industries
# 72            Marillyn Hewson                  Lockheed Martin
# 73                 Steve Rowe                  Marks & Spencer
# 74          Chris Kempczinski                       McDonald's
# 75              Bob Sternfels               McKinsey & Company
# 76        Steven A. Kandarian                          MetLife
# 77               Isaac Larian                MGA Entertainment
# 78              Satya Nadella                        Microsoft
# 79            James P. Gorman                   Morgan Stanley
# 80                 Jeff Shell                     NBCUniversal
# 81       Robert James Thomson                        News Corp
# 82              Mark Thompson           New York Times Company
# 83                Mark Parker                             Nike
# 84             Pekka Lundmark                            Nokia
# 85          Vasant Narasimhan                         Novartis
# 86          Tatsumi Kimishima                         Nintendo
# 87                 Safra Catz               Oracle Corporation
# 88                  Mark Hurd               Oracle Corporation
# 89             Ramon Laguarta                          PepsiCo
# 90              Albert Bourla                           Pfizer
# 91            David S. Taylor                 Procter & Gamble
# 92            John Strangfeld             Prudential Financial
# 93                 Alan Joyce                           Qantas
# 94                Anil Ambani                   Reliance Group
# 95              Mukesh Ambani              Reliance Industries
# 96                Luca de Meo                          Renault
# 97             David I. McKay             Royal Bank of Canada
# 98                Ross McEwan           Royal Bank of Scotland
# 99            Ben van Beurden                Royal Dutch Shell
# 100           Michael O'Leary                          Ryanair
# 101       Douglas L. Peterson                       S&P Global
# 102              Oh-Hyun Kwon                          Samsung
# 103           Christian Klein                              SAP
# 104  Herbert Fisk Johnson III                       SC Johnson
# 105      Jean-Pascal Tricoire               Schneider Electric
# 106            Peter Harrison                        Schroders
# 107           Chua Sock Koong                          Singtel
# 108             Masayoshi Son                         SoftBank
# 109               Tony Aquila                  Solera Holdings
# 110                 Elon Musk                           SpaceX
# 111          Robert E. Jordan               Southwest Airlines
# 112        J. Clifford Hudson                Sonic Corporation
# 113              Brian Niccol                        Starbucks
# 114              Raymond Kwok          Sun Hung Kai Properties
# 115     William H. Rogers Jr.                   SunTrust Banks
# 116             Brian Cornell               Target Corporation
# 117         Rajesh Gopinathan        Tata Consultancy Services
# 118              Li Dongsheng                  TCL Corporation
# 119                 Andy Penn                          Telstra
# 120                Dave Lewis                            Tesco
# 121                 Elon Musk                            Tesla
# 122         Alan D. Schnitzer          The Travelers Companies
# 123               Akio Toyoda                           Toyota
# 124               Scott Kirby                  United Airlines
# 125            Brian Thompson                 UnitedHealthcare
# 126              Ralph Hamers                              UBS
# 127             Hans Vestberg           Verizon Communications
# 128             Robert Bakish                        ViacomCBS
# 129            Ryan McInerney                        Visa Inc.
# 130            Vittorio Colao                         Vodafone
# 131             Herbert Diess                 Volkswagen Group
# 132               Robert Iger              Walt Disney Company
# 133           Stefano Pessina         Walgreens Boots Alliance
# 134             Doug McMillon                          Walmart
# 135               Ann Sarnoff                  Warner Brothers
# 136               Jason Kilar                      WarnerMedia
# 137            Charles Scharf                      Wells Fargo
# 138               John Mackey               Whole Foods Market
# 139               Rich Barton                     Zillow Group
#
#                    clean_name                 born     _merge
# 0                 Julie Sweet                  NaT       both
# 1        Kumar Mangalam Birla  1967-06-14 00:00:00       both
# 2            Shantanu Narayen  1963-05-27 00:00:00       both
# 3             Guillaume Faury  1968-02-22 00:00:00       both
# 4                    Eddie Wu                  NaT       both
# 5                  Andy Jassy  1968-01-13 00:00:00       both
# 6                     Lisa Su                  NaT       both
# 7              Stephen Squeri                  NaT       both
# 8           Joseph R. Swedish  1951-05-17 00:00:00       both
# 9                    Tim Cook  1960-11-01 00:00:00       both
# 10              Aditya Mittal  1976-01-22 00:00:00       both
# 11               John Stankey                  NaT       both
# 12           Charles Woodburn  1971-03-11 00:00:00       both
# 13              Tapan Singhel  1966-08-12 00:00:00       both
# 14         Carlos Torres Vila                  NaT       both
# 15             Brian Moynihan  1959-10-09 00:00:00       both
# 16       C.S. Venkatakrishnan                  NaT       both
# 17             Warren Buffett  1930-08-30 00:00:00       both
# 18                Hubert Joly  1959-08-11 00:00:00       both
# 19        Sunil Bharti Mittal  1957-10-23 00:00:00       both
# 20      Stephen A. Schwarzman  1947-02-14 00:00:00       both
# 21                 Mike Henry                  NaT       both
# 22               Oliver Zipse  1964-02-07 00:00:00       both
# 23              Kelly Ortberg                  NaT       both
# 24                Rich Lesser                  NaT       both
# 25                 Bob Dudley  1955-09-14 00:00:00       both
# 26                   Hock Tan                  NaT       both
# 27            Denise Morrison  1954-01-13 00:00:00       both
# 28          Mark Shuttleworth  1973-09-18 00:00:00       both
# 29           Richard Fairbank  1950-09-18 00:00:00       both
# 30                Jim Umpleby                  NaT       both
# 31             Evan Greenberg                  NaT       both
# 32                        NaN                  NaN  left_only
# 33              Chuck Robbins                  NaT       both
# 34                Jane Fraser                  NaT       both
# 35              James Quincey  1965-01-08 00:00:00       both
# 36           Brian L. Roberts  1959-06-28 00:00:00       both
# 37           Thomas Gottstein                  NaT       both
# 38                        NaN                  NaN  left_only
# 39               Michael Dell  1965-02-23 00:00:00       both
# 40                 Ed Bastian  1957-06-06 00:00:00       both
# 41           Christian Sewing  1970-04-24 00:00:00       both
# 42               Tobias Meyer                  NaT       both
# 43            Edward D. Breen                  NaT       both
# 44                Devin Wenig                  NaT       both
# 45                        NaN                  NaN  left_only
# 46               Darren Woods  1965-12-16 00:00:00       both
# 47           Carmine Di Sibio  1963-03-23 00:00:00       both
# 48            Mark Zuckerberg  1984-05-14 00:00:00       both
# 49            Raj Subramaniam                  NaT       both
# 50          Sergio Marchionne                  NaT       both
# 51            Abigail Johnson  1961-12-19 00:00:00       both
# 52              James Hackett                  NaT       both
# 53                  Terry Gou  1950-10-18 00:00:00       both
# 54            Lachlan Murdoch  1971-09-08 00:00:00       both
# 55                 Ryan Cohen                  NaT       both
# 56            Phebe Novakovic                  NaT       both
# 57       H. Lawrence Culp Jr.                  NaT       both
# 58              Mary T. Barra  1961-12-24 00:00:00       both
# 59              Emma Walmsley                  NaT       both
# 60           David M. Solomon                  NaT       both
# 61              Sundar Pichai  1972-06-10 00:00:00       both
# 62              C Vijayakumar                  NaT       both
# 63               Antonio Neri  1576-02-29 00:00:00       both
# 64            Darius Adamczyk  1966-02-08 00:00:00       both
# 65                 Noel Quinn                  NaT       both
# 66             Arvind Krishna  1962-11-23 00:00:00       both
# 67               Salil Parekh  1964-06-05 00:00:00       both
# 68              Pat Gelsinger  1961-03-05 00:00:00       both
# 69                James Dimon  1956-03-13 00:00:00       both
# 70              Pieter Elbers  1970-05-11 00:00:00       both
# 71            Charles G. Koch  1935-11-01 00:00:00       both
# 72            Marillyn Hewson  1953-12-27 00:00:00       both
# 73                 Steve Rowe  1965-01-19 00:00:00       both
# 74          Chris Kempczinski                  NaT       both
# 75              Bob Sternfels                  NaT       both
# 76        Steven A. Kandarian                  NaT       both
# 77               Isaac Larian  1954-03-28 00:00:00       both
# 78              Satya Nadella  1967-08-19 00:00:00       both
# 79            James P. Gorman  1958-07-14 00:00:00       both
# 80                 Jeff Shell                  NaT       both
# 81       Robert James Thomson  1961-03-11 00:00:00       both
# 82              Mark Thompson                  NaT       both
# 83                Mark Parker  1955-10-21 00:00:00       both
# 84             Pekka Lundmark  1963-12-09 00:00:00       both
# 85          Vasant Narasimhan  1976-08-26 00:00:00       both
# 86          Tatsumi Kimishima  1950-04-21 00:00:00       both
# 87                 Safra Catz                  NaT       both
# 88                  Mark Hurd  1957-01-01 00:00:00       both
# 89             Ramon Laguarta                  NaT       both
# 90              Albert Bourla  1961-10-21 00:00:00       both
# 91            David S. Taylor  1958-04-20 00:00:00       both
# 92            John Strangfeld                  NaT       both
# 93                 Alan Joyce                  NaT       both
# 94                Anil Ambani  1959-06-04 00:00:00       both
# 95              Mukesh Ambani  1957-04-19 00:00:00       both
# 96                Luca de Meo  1967-06-13 00:00:00       both
# 97             David I. McKay                  NaT       both
# 98                Ross McEwan  1957-07-16 00:00:00       both
# 99            Ben van Beurden  1958-04-23 00:00:00       both
# 100                       NaN                  NaN  left_only
# 101       Douglas L. Peterson                  NaT       both
# 102              Oh-Hyun Kwon                  NaT       both
# 103           Christian Klein  1980-05-04 00:00:00       both
# 104  Herbert Fisk Johnson III  1958-05-19 00:00:00       both
# 105      Jean-Pascal Tricoire                  NaT       both
# 106            Peter Harrison                  NaT       both
# 107           Chua Sock Koong  1957-09-14 00:00:00       both
# 108             Masayoshi Son  1957-08-11 00:00:00       both
# 109               Tony Aquila                  NaT       both
# 110                 Elon Musk  1971-06-28 00:00:00       both
# 111          Robert E. Jordan                  NaT       both
# 112        J. Clifford Hudson                  NaT       both
# 113              Brian Niccol  1974-08-16 00:00:00       both
# 114              Raymond Kwok                  NaT       both
# 115     William H. Rogers Jr.                  NaT       both
# 116             Brian Cornell                  NaT       both
# 117         Rajesh Gopinathan                  NaT       both
# 118              Li Dongsheng                  NaT       both
# 119                 Andy Penn                  NaT       both
# 120                Dave Lewis                  NaT       both
# 121                 Elon Musk  1971-06-28 00:00:00       both
# 122         Alan D. Schnitzer                  NaT       both
# 123               Akio Toyoda  1956-05-03 00:00:00       both
# 124               Scott Kirby  1967-08-13 00:00:00       both
# 125            Brian Thompson                  NaT       both
# 126              Ralph Hamers  1966-05-25 00:00:00       both
# 127             Hans Vestberg  1965-06-23 00:00:00       both
# 128             Robert Bakish  1963-12-14 00:00:00       both
# 129            Ryan McInerney                  NaT       both
# 130            Vittorio Colao  1961-10-03 00:00:00       both
# 131             Herbert Diess  1958-10-24 00:00:00       both
# 132               Robert Iger  1951-02-10 00:00:00       both
# 133           Stefano Pessina  1941-06-04 00:00:00       both
# 134             Doug McMillon  1966-10-17 00:00:00       both
# 135               Ann Sarnoff                  NaT       both
# 136               Jason Kilar  1971-04-26 00:00:00       both
# 137            Charles Scharf  1965-04-24 00:00:00       both
# 138               John Mackey                  NaT       both
# 139               Rich Barton                  NaT       both

# %%
pd.set_option('display.max_rows', 50)
result_df = company_ceos_df[['Executive', 'Company']].merge(exec_df[['clean_name', 'born']],
                                                left_on=['Executive'],
                                                right_on=['clean_name'], how="outer", indicator=True)

result_df[result_df['_merge'] != 'both']
# Out:
#           Executive     Company          clean_name                 born  \
# 12              NaN         NaN   B%C3%B6rje Ekholm                  NaT
# 21     Börje Ekholm    Ericsson                 NaN                  NaN
# 65   Jane N. Fraser   Citigroup                 NaN                  NaN
# 90              NaN         NaN   Michael O%27Leary                  NaT
# 91  Michael O'Leary     Ryanair                 NaN                  NaN
# 96              NaN         NaN  Ola K%C3%A4llenius  1969-06-11 00:00:00
# 97    Ola Källenius  Daimler AG                 NaN                  NaN
#
#         _merge
# 12  right_only
# 21   left_only
# 65   left_only
# 90  right_only
# 91   left_only
# 96  right_only
# 97   left_only

# %% [markdown]
# ## Composing Joins

# %%
pd.read_sql_query('select Executive, Company, born  from company_ceos ' +\
                  'join executives on Executive=clean_name join company_data cd on Company=cd.name ' +\
                  'where born is not null', conn)
# Out:
#                Executive                 Company                 born
# 0               Eddie Wu                 Alibaba                  NaT
# 1             Andy Jassy                  Amazon  1968-01-13 00:00:00
# 2       Charles Woodburn             BAE Systems  1971-03-11 00:00:00
# 3      Mark Shuttleworth               Canonical  1973-09-18 00:00:00
# 4       Brian L. Roberts                 Comcast  1959-06-28 00:00:00
# 5            Devin Wenig                    eBay                  NaT
# 6        Mark Zuckerberg                Facebook  1984-05-14 00:00:00
# 7        Phebe Novakovic        General Dynamics                  NaT
# 8   H. Lawrence Culp Jr.        General Electric                  NaT
# 9          Sundar Pichai                  Google  1972-06-10 00:00:00
# 10       Darius Adamczyk               Honeywell  1966-02-08 00:00:00
# 11       Marillyn Hewson         Lockheed Martin  1953-12-27 00:00:00
# 12  Robert James Thomson               News Corp  1961-03-11 00:00:00
# 13          Brian Niccol               Starbucks  1974-08-16 00:00:00
# 14            Dave Lewis                   Tesco                  NaT
# 15         Hans Vestberg  Verizon Communications  1965-06-23 00:00:00

# %%
pd.read_sql_query('select * from company_ceos ' +\
                  'join executives on Executive=clean_name join company_data cd on Company=cd.name ' +\
                  'where born is not null', conn)
# Out:
#     index                 Company             Executive  \
# 0       4                 Alibaba              Eddie Wu
# 1       5                  Amazon            Andy Jassy
# 2      12             BAE Systems      Charles Woodburn
# 3      28               Canonical     Mark Shuttleworth
# 4      36                 Comcast      Brian L. Roberts
# 5      44                    eBay           Devin Wenig
# 6      48                Facebook       Mark Zuckerberg
# 7      56        General Dynamics       Phebe Novakovic
# 8      57        General Electric  H. Lawrence Culp Jr.
# 9      61                  Google         Sundar Pichai
# 10     64               Honeywell       Darius Adamczyk
# 11     72         Lockheed Martin       Marillyn Hewson
# 12     81               News Corp  Robert James Thomson
# 13    113               Starbucks          Brian Niccol
# 14    120                   Tesco            Dave Lewis
# 15    127  Verizon Communications         Hans Vestberg
#
#                                Title    Since  \
# 0                Director and CEO[5]  2023[6]
# 1               CEO and president[7]     2021
# 2        Chief Executive Officer[14]     2008
# 3                Founder and CEO[28]     2017
# 4               Chairman and CEO[35]     2002
# 5              President and CEO[41]     2015
# 6                   Chairman and CEO     2004
# 7               Chairman and CEO[49]     2014
# 8                   Chairman and CEO     2018
# 9                            CEO[53]     2015
# 10  Chairman, President, and CEO[56]     2017
# 11   Chairman, president and CEO[63]     2013
# 12                           CEO[71]     2013
# 13             Chairman and CEO[101]     2024
# 14                    Group CEO[108]     2014
# 15             Chairman and CEO[115]     2018
#
#                                                                                      Notes  \
# 0                                                                                      nan
# 1                                                  Officially succeeded founder Jeff Bezos
# 2                                                                       Succeeded Ian King
# 3                                          Stepped down as CEO in 2009 and resumed in 2017
# 4                                          Son of Ralph J. Roberts, the founder of Comcast
# 5                             Third CEO of the company, after Meg Whitman and John Donahoe
# 6                                                              Co-founded Facebook in 2004
# 7   Worked for the Central Intelligence Agency and the United States Department of Defense
# 8              Prior to joining GE, Culp worked at Danaher Corporation in Washington, D.C.
# 9                                       Former director of Jive Software from 2011 to 2013
# 10                                    Succeeded David M. Cote (now the executive chairman)
# 11                     Also serves on the board of Sandia National Laboratories and DuPont
# 12                                   Previously managing editor of The Wall Street Journal
# 13                                  Previously CEO of Chipotle; succeeds Laxman Narasimhan
# 14                                                                Previously with Unilever
# 15                                                                  Replaced Lowell McAdam
#
#        Updated  index                  name  \
# 0   2024-07-19      4              Eddie_Wu
# 1   2024-10-20      5            Andy_Jassy
# 2   2018-10-01     12      Charles_Woodburn
# 3   2017-11-14     28     Mark_Shuttleworth
# 4   2017-11-14     35      Brian_L._Roberts
# 5   2017-11-14     43           Devin_Wenig
# 6   2017-11-14     47       Mark_Zuckerberg
# 7   2017-11-14     55       Phebe_Novakovic
# 8   2018-10-01     56  H._Lawrence_Culp_Jr.
# 9   2017-11-13     60         Sundar_Pichai
# 10  2017-11-13     63       Darius_Adamczyk
# 11  2017-11-13     71       Marillyn_Hewson
# 12  2017-11-12     80  Robert_James_Thomson
# 13  2024-08-27    112          Brian_Niccol
# 14  2017-11-11    119            Dave_Lewis
# 15  2019-03-31    126         Hans_Vestberg
#
#                                                   page  ... state_code  \
# 0               https://en.wikipedia.org/wiki/Eddie_Wu  ...       None
# 1             https://en.wikipedia.org/wiki/Andy_Jassy  ...         WA
# 2       https://en.wikipedia.org/wiki/Charles_Woodburn  ...         MD
# 3      https://en.wikipedia.org/wiki/Mark_Shuttleworth  ...       None
# 4       https://en.wikipedia.org/wiki/Brian_L._Roberts  ...         PA
# 5            https://en.wikipedia.org/wiki/Devin_Wenig  ...         CA
# 6        https://en.wikipedia.org/wiki/Mark_Zuckerberg  ...         CA
# 7        https://en.wikipedia.org/wiki/Phebe_Novakovic  ...         VA
# 8   https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.  ...         CT
# 9          https://en.wikipedia.org/wiki/Sundar_Pichai  ...         CA
# 10       https://en.wikipedia.org/wiki/Darius_Adamczyk  ...         NJ
# 11       https://en.wikipedia.org/wiki/Marillyn_Hewson  ...         MD
# 12  https://en.wikipedia.org/wiki/Robert_James_Thomson  ...         NY
# 13          https://en.wikipedia.org/wiki/Brian_Niccol  ...         WA
# 14            https://en.wikipedia.org/wiki/Dave_Lewis  ...       None
# 15         https://en.wikipedia.org/wiki/Hans_Vestberg  ...         NY
#
#               region           city funding_rounds  founded_at founded_month  \
# 0           Hangzhou       Hangzhou              4  01/06/1999       1999-06
# 1            Seattle        Seattle              1  01/01/1994       1994-01
# 2   Washington, D.C.      Rockville              2  01/11/1999       1999-11
# 3             London         London              1  01/01/2004       2004-01
# 4       Philadelphia   Philadelphia              1  01/01/1963       1963-01
# 5        SF Bay Area       San Jose              1  01/09/1995       1995-09
# 6        SF Bay Area     Menlo Park             11  04/02/2004       2004-02
# 7   Washington, D.C.   Falls Church              3  01/01/1952       1952-01
# 8           Hartford      Fairfield              1  1890-01-01          None
# 9        SF Bay Area  Mountain View              2  07/09/1998       1998-09
# 10            Newark     Morristown              1  23/04/1985       1985-04
# 11  Washington, D.C.       Bethesda              2  01/03/1995       1995-03
# 12     New York City       New York              1  01/01/1980       1980-01
# 13           Seattle        Seattle              1  30/03/1971       1971-03
# 14       GBR - Other       Cheshunt              2  01/01/1919       1919-01
# 15     New York City       New York              5  07/10/1983       1983-10
#
#    founded_quarter founded_year first_funding_at last_funding_at
# 0          1999-Q2       1999.0       01/10/1999      11/08/2005
# 1          1994-Q1       1994.0       01/07/1995      01/07/1995
# 2          1999-Q4       1999.0       30/11/2009      10/09/2010
# 3          2004-Q1       2004.0       16/08/2013      16/08/2013
# 4          1963-Q1       1963.0       08/05/2013      08/05/2013
# 5          1995-Q3       1995.0       01/06/1997      01/06/1997
# 6          2004-Q1       2004.0       01/09/2004      21/01/2011
# 7          1952-Q1       1952.0       05/08/2009      10/09/2010
# 8             None          NaN       19/11/2009      19/11/2009
# 9          1998-Q3       1998.0       01/08/1998      07/06/1999
# 10         1985-Q2       1985.0       27/10/2009      27/10/2009
# 11         1995-Q1       1995.0       06/07/2009      22/11/2010
# 12         1980-Q1       1980.0       08/01/2010      08/01/2010
# 13         1971-Q1       1971.0       01/02/1991      01/02/1991
# 14         1919-Q1       1919.0       30/07/2009      15/07/2010
# 15         1983-Q4       1983.0       26/01/2010      28/02/2014
#
# [16 rows x 31 columns]

# %%
company_ceos_df.merge(exec_df,
                      left_on=['Executive'],
                      right_on=['clean_name']).\
                      merge(company_data_df,
                            left_on='Company',
                            right_on='name')
# Out:
#                    Company             Executive  \
# 0                  Alibaba              Eddie Wu
# 1                   Amazon            Andy Jassy
# 2              BAE Systems      Charles Woodburn
# 3                Canonical     Mark Shuttleworth
# 4                  Comcast      Brian L. Roberts
# 5                     eBay           Devin Wenig
# 6                 Facebook       Mark Zuckerberg
# 7         General Dynamics       Phebe Novakovic
# 8         General Electric  H. Lawrence Culp Jr.
# 9                   Google         Sundar Pichai
# 10               Honeywell       Darius Adamczyk
# 11         Lockheed Martin       Marillyn Hewson
# 12               News Corp  Robert James Thomson
# 13               Starbucks          Brian Niccol
# 14                   Tesco            Dave Lewis
# 15  Verizon Communications         Hans Vestberg
#
#                                Title    Since  \
# 0                Director and CEO[5]  2023[6]
# 1               CEO and president[7]     2021
# 2        Chief Executive Officer[14]     2008
# 3                Founder and CEO[28]     2017
# 4               Chairman and CEO[35]     2002
# 5              President and CEO[41]     2015
# 6                   Chairman and CEO     2004
# 7               Chairman and CEO[49]     2014
# 8                   Chairman and CEO     2018
# 9                            CEO[53]     2015
# 10  Chairman, President, and CEO[56]     2017
# 11   Chairman, president and CEO[63]     2013
# 12                           CEO[71]     2013
# 13             Chairman and CEO[101]     2024
# 14                    Group CEO[108]     2014
# 15             Chairman and CEO[115]     2018
#
#                                                                                      Notes  \
# 0                                                                                      NaN
# 1                                                  Officially succeeded founder Jeff Bezos
# 2                                                                       Succeeded Ian King
# 3                                          Stepped down as CEO in 2009 and resumed in 2017
# 4                                          Son of Ralph J. Roberts, the founder of Comcast
# 5                             Third CEO of the company, after Meg Whitman and John Donahoe
# 6                                                              Co-founded Facebook in 2004
# 7   Worked for the Central Intelligence Agency and the United States Department of Defense
# 8              Prior to joining GE, Culp worked at Danaher Corporation in Washington, D.C.
# 9                                       Former director of Jive Software from 2011 to 2013
# 10                                    Succeeded David M. Cote (now the executive chairman)
# 11                     Also serves on the board of Sandia National Laboratories and DuPont
# 12                                   Previously managing editor of The Wall Street Journal
# 13                                  Previously CEO of Chipotle; succeeds Laxman Narasimhan
# 14                                                                Previously with Unilever
# 15                                                                  Replaced Lowell McAdam
#
#        Updated                name_x  \
# 0   2024-07-19              Eddie_Wu
# 1   2024-10-20            Andy_Jassy
# 2   2018-10-01      Charles_Woodburn
# 3   2017-11-14     Mark_Shuttleworth
# 4   2017-11-14      Brian_L._Roberts
# 5   2017-11-14           Devin_Wenig
# 6   2017-11-14       Mark_Zuckerberg
# 7   2017-11-14       Phebe_Novakovic
# 8   2018-10-01  H._Lawrence_Culp_Jr.
# 9   2017-11-13         Sundar_Pichai
# 10  2017-11-13       Darius_Adamczyk
# 11  2017-11-13       Marillyn_Hewson
# 12  2017-11-12  Robert_James_Thomson
# 13  2024-08-27          Brian_Niccol
# 14  2017-11-11            Dave_Lewis
# 15  2019-03-31         Hans_Vestberg
#
#                                                   page                 born  \
# 0               https://en.wikipedia.org/wiki/Eddie_Wu                  NaT
# 1             https://en.wikipedia.org/wiki/Andy_Jassy  1968-01-13 00:00:00
# 2       https://en.wikipedia.org/wiki/Charles_Woodburn  1971-03-11 00:00:00
# 3      https://en.wikipedia.org/wiki/Mark_Shuttleworth  1973-09-18 00:00:00
# 4       https://en.wikipedia.org/wiki/Brian_L._Roberts  1959-06-28 00:00:00
# 5            https://en.wikipedia.org/wiki/Devin_Wenig                  NaT
# 6        https://en.wikipedia.org/wiki/Mark_Zuckerberg  1984-05-14 00:00:00
# 7        https://en.wikipedia.org/wiki/Phebe_Novakovic                  NaT
# 8   https://en.wikipedia.org/wiki/H._Lawrence_Culp_Jr.                  NaT
# 9          https://en.wikipedia.org/wiki/Sundar_Pichai  1972-06-10 00:00:00
# 10       https://en.wikipedia.org/wiki/Darius_Adamczyk  1966-02-08 00:00:00
# 11       https://en.wikipedia.org/wiki/Marillyn_Hewson  1953-12-27 00:00:00
# 12  https://en.wikipedia.org/wiki/Robert_James_Thomson  1961-03-11 00:00:00
# 13          https://en.wikipedia.org/wiki/Brian_Niccol  1974-08-16 00:00:00
# 14            https://en.wikipedia.org/wiki/Dave_Lewis                  NaT
# 15         https://en.wikipedia.org/wiki/Hans_Vestberg  1965-06-23 00:00:00
#
#               clean_name  ... state_code            region           city  \
# 0               Eddie Wu  ...        NaN          Hangzhou       Hangzhou
# 1             Andy Jassy  ...         WA           Seattle        Seattle
# 2       Charles Woodburn  ...         MD  Washington, D.C.      Rockville
# 3      Mark Shuttleworth  ...        NaN            London         London
# 4       Brian L. Roberts  ...         PA      Philadelphia   Philadelphia
# 5            Devin Wenig  ...         CA       SF Bay Area       San Jose
# 6        Mark Zuckerberg  ...         CA       SF Bay Area     Menlo Park
# 7        Phebe Novakovic  ...         VA  Washington, D.C.   Falls Church
# 8   H. Lawrence Culp Jr.  ...         CT          Hartford      Fairfield
# 9          Sundar Pichai  ...         CA       SF Bay Area  Mountain View
# 10       Darius Adamczyk  ...         NJ            Newark     Morristown
# 11       Marillyn Hewson  ...         MD  Washington, D.C.       Bethesda
# 12  Robert James Thomson  ...         NY     New York City       New York
# 13          Brian Niccol  ...         WA           Seattle        Seattle
# 14            Dave Lewis  ...        NaN       GBR - Other       Cheshunt
# 15         Hans Vestberg  ...         NY     New York City       New York
#
#    funding_rounds  founded_at founded_month founded_quarter founded_year  \
# 0               4  01/06/1999       1999-06         1999-Q2       1999.0
# 1               1  01/01/1994       1994-01         1994-Q1       1994.0
# 2               2  01/11/1999       1999-11         1999-Q4       1999.0
# 3               1  01/01/2004       2004-01         2004-Q1       2004.0
# 4               1  01/01/1963       1963-01         1963-Q1       1963.0
# 5               1  01/09/1995       1995-09         1995-Q3       1995.0
# 6              11  04/02/2004       2004-02         2004-Q1       2004.0
# 7               3  01/01/1952       1952-01         1952-Q1       1952.0
# 8               1  1890-01-01           NaN             NaN          NaN
# 9               2  07/09/1998       1998-09         1998-Q3       1998.0
# 10              1  23/04/1985       1985-04         1985-Q2       1985.0
# 11              2  01/03/1995       1995-03         1995-Q1       1995.0
# 12              1  01/01/1980       1980-01         1980-Q1       1980.0
# 13              1  30/03/1971       1971-03         1971-Q1       1971.0
# 14              2  01/01/1919       1919-01         1919-Q1       1919.0
# 15              5  07/10/1983       1983-10         1983-Q4       1983.0
#
#    first_funding_at last_funding_at
# 0        01/10/1999      11/08/2005
# 1        01/07/1995      01/07/1995
# 2        30/11/2009      10/09/2010
# 3        16/08/2013      16/08/2013
# 4        08/05/2013      08/05/2013
# 5        01/06/1997      01/06/1997
# 6        01/09/2004      21/01/2011
# 7        05/08/2009      10/09/2010
# 8        19/11/2009      19/11/2009
# 9        01/08/1998      07/06/1999
# 10       27/10/2009      27/10/2009
# 11       06/07/2009      22/11/2010
# 12       08/01/2010      08/01/2010
# 13       01/02/1991      01/02/1991
# 14       30/07/2009      15/07/2010
# 15       26/01/2010      28/02/2014
#
# [16 rows x 28 columns]

# %% [markdown]
# # Lecture Module 3: Validating and Cleaning Data
#
# How do we know our data is good?  We can create rules that trigger when the data fails some particular set of **constraints**.

# %%
# Test with validation rules

replace_item = ''

failed = False
for name in exec_df['clean_name']:
  if not name.replace(' ', replace_item).\
          replace('.', replace_item).\
          replace('\'',replace_item).\
          replace('-',replace_item).isalpha():
    print ("Illegal name %s"%name)
    failed = True

if failed:
  print('Found illegal names!')
# Out:
# Illegal name Ola K%C3%A4llenius
# Illegal name B%C3%B6rje Ekholm
# Illegal name Michael O%27Leary
# Found illegal names!

# %% [markdown]
# ## Data Cleaning: Fixing the Errors
#
# One approach we could take is to realize that these are all strings in which accented characters are specially coded for use in (Wikipedia) URLs.  For instance, %C3 is a hex character code for an accented "u".  We can use a function called `unqote` to fix this...

# %%
from urllib.parse import unquote

exec_df['clean_name'].apply(unquote)
# Out:
# 0               Julie Sweet
# 1      Kumar Mangalam Birla
# 2          Shantanu Narayen
# 3           Guillaume Faury
# 4                  Eddie Wu
#                ...
# 134             Ann Sarnoff
# 135             Jason Kilar
# 136          Charles Scharf
# 137             John Mackey
# 138             Rich Barton
# Name: clean_name, Length: 138, dtype: object

# %% [markdown]
# ## More Generally: Data Validation Tools
#
# Are there tools to help us validate data?  Of course!  We see an [example](https://validators.readthedocs.io/en/latest/) of one such tool, simply called `validators`, below.  There are many others in the data cleaning literature.

# %%
# !pip install validators
# Out:
# Collecting validators
#   Downloading validators-0.34.0-py3-none-any.whl.metadata (3.8 kB)
# Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: validators
# Successfully installed validators-0.34.0

# %%
import validators.url

# Are all of the URLs valid?
exec_df['page'].apply(validators.url)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 134    True
# 135    True
# 136    True
# 137    True
# 138    True
# Name: page, Length: 138, dtype: bool

# %% [markdown]
# ## Validation against a master list
#
# We can also compare against "master" lists (in tables).  For example, company info about stock ticker symbols can be compared against the full list of symbols; states and countries can be compared against definitive lists.
#
# Suppose we want to confirm that `company_data_df` has valid country codes.

# %%
company_data_df[['name','country_code']]
# Out:
#                                 name country_code
# 0                           #waywire          USA
# 1                 &TV Communications          USA
# 2                  'Rock' Your Paper          EST
# 3                  (In)Touch Network          GBR
# 4                         +n (PlusN)          USA
# ...                              ...          ...
# 47753                          Zzish          GBR
# 47754  ZZNode Science and Technology          CHN
# 47755          Zzzzapp Wireless ltd.          HRV
# 47756                  [a]list games          NaN
# 47757                          [x+1]          USA
#
# [47758 rows x 2 columns]

# %% [markdown]
# TSome of these are NaNs -- let's drop them...

# %% [markdown]
# From someone's Github content, here's a nice list of all countries and region codes.

# %%
countries_df = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")

display(countries_df)
# Out:
#                   name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0          Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1        Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2              Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3              Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4       American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
# ..                 ...     ...     ...           ...            ...      ...
# 244  Wallis and Futuna      WF     WLF           876  ISO 3166-2:WF  Oceania
# 245     Western Sahara      EH     ESH           732  ISO 3166-2:EH   Africa
# 246              Yemen      YE     YEM           887  ISO 3166-2:YE     Asia
# 247             Zambia      ZM     ZMB           894  ISO 3166-2:ZM   Africa
# 248           Zimbabwe      ZW     ZWE           716  ISO 3166-2:ZW   Africa
#
#              sub-region intermediate-region  region-code  sub-region-code  \
# 0         Southern Asia                 NaN        142.0             34.0
# 1       Northern Europe                 NaN        150.0            154.0
# 2       Southern Europe                 NaN        150.0             39.0
# 3       Northern Africa                 NaN          2.0             15.0
# 4             Polynesia                 NaN          9.0             61.0
# ..                  ...                 ...          ...              ...
# 244           Polynesia                 NaN          9.0             61.0
# 245     Northern Africa                 NaN          2.0             15.0
# 246        Western Asia                 NaN        142.0            145.0
# 247  Sub-Saharan Africa      Eastern Africa          2.0            202.0
# 248  Sub-Saharan Africa      Eastern Africa          2.0            202.0
#
#      intermediate-region-code
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 244                       NaN
# 245                       NaN
# 246                       NaN
# 247                      14.0
# 248                      14.0
#
# [249 rows x 11 columns]

# %%
validated = company_data_df.merge(countries_df, left_on=['country_code'], right_on=['alpha-3'],
                      how='left', indicator=True)

validated[validated['_merge'] != 'both']
# Out:
#                              permalink             name_x  \
# 8                /organization/0-6-com            0-6.com
# 19          /organization/1000-markets       1000 Markets
# 25              /organization/100du-tv           100du.tv
# 30                 /organization/10sec              10sec
# 35     /organization/115-network-disks  115 network disks
# ...                                ...                ...
# 47707               /organization/zura              Zura!
# 47712            /organization/zursh-2              Zursh
# 47729          /organization/zwoor-com          zwoor.com
# 47743              /organization/zympi              Zympi
# 47756       /organization/a-list-games      [a]list games
#
#                      homepage_url  \
# 8              http://www.0-6.com
# 19     http://www.1000markets.com
# 25           http://www.100du.com
# 30                 http://10s.ec/
# 35            http://www.115.com/
# ...                           ...
# 47707      http://www.zura.com.br
# 47712       http://www.zursh.com/
# 47729        http://www.zwoor.com
# 47743        http://www.zympi.com
# 47756   http://www.alistgames.com
#
#                                                               category_list  \
# 8                                                             |Curated Web|
# 19                                            |Marketplaces|Art|E-Commerce|
# 25                                                            |Hospitality|
# 30                             |Social Commerce|E-Commerce|Mobile Commerce|
# 35                                                              |Education|
# ...                                                                     ...
# 47707                                                          |E-Commerce|
# 47712                                                                   NaN
# 47729  |Meeting Software|Polling|Surveys|Android|iPhone|iPad|Events|Mobile|
# 47743                                       |Networking|Web Hosting|Mobile|
# 47756                                                               |Games|
#
#                   market funding_total_usd     status country_code state_code  \
# 8            Curated Web        2 000 000   operating          NaN        NaN
# 19          Marketplaces          500 000    acquired          NaN        NaN
# 25           Hospitality        3 000 000   operating          NaN        NaN
# 30      Mobile Commerce         1 600 000         NaN          NaN        NaN
# 35             Education              -     operating          NaN        NaN
# ...                  ...               ...        ...          ...        ...
# 47707        E-Commerce               -     operating          NaN        NaN
# 47712                NaN           25 000   operating          NaN        NaN
# 47729           Polling           100 000   operating          NaN        NaN
# 47743       Web Hosting               -     operating          NaN        NaN
# 47756             Games         9 300 000   operating          NaN        NaN
#
#       region_x  ... alpha-3  country-code iso_3166-2 region_y sub-region  \
# 8          NaN  ...     NaN           NaN        NaN      NaN        NaN
# 19         NaN  ...     NaN           NaN        NaN      NaN        NaN
# 25         NaN  ...     NaN           NaN        NaN      NaN        NaN
# 30         NaN  ...     NaN           NaN        NaN      NaN        NaN
# 35         NaN  ...     NaN           NaN        NaN      NaN        NaN
# ...        ...  ...     ...           ...        ...      ...        ...
# 47707      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47712      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47729      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47743      NaN  ...     NaN           NaN        NaN      NaN        NaN
# 47756      NaN  ...     NaN           NaN        NaN      NaN        NaN
#
#        intermediate-region region-code sub-region-code  \
# 8                      NaN         NaN             NaN
# 19                     NaN         NaN             NaN
# 25                     NaN         NaN             NaN
# 30                     NaN         NaN             NaN
# 35                     NaN         NaN             NaN
# ...                    ...         ...             ...
# 47707                  NaN         NaN             NaN
# 47712                  NaN         NaN             NaN
# 47729                  NaN         NaN             NaN
# 47743                  NaN         NaN             NaN
# 47756                  NaN         NaN             NaN
#
#       intermediate-region-code     _merge
# 8                          NaN  left_only
# 19                         NaN  left_only
# 25                         NaN  left_only
# 30                         NaN  left_only
# 35                         NaN  left_only
# ...                        ...        ...
# 47707                      NaN  left_only
# 47712                      NaN  left_only
# 47729                      NaN  left_only
# 47743                      NaN  left_only
# 47756                      NaN  left_only
#
# [5164 rows x 30 columns]

# %% [markdown]
# ## Record Linking: Working around the Errors
#
# Rather than figuring out how to clean these characters, we'll instead look at doing approximate matching.

# %% [markdown]
# Now we'll need to import some similarity matching code, to do approximate match between the original names and those returned by Wikipedia

# %%
# We are going to match the strings approximately, via "n-grams" or "q-grams" (sequences of n or q characters)
# Here it's five-grams

tok = sm.QgramTokenizer(qval=5,return_set=True)

# %%
import py_stringsimjoin as ssj
import py_stringmatching as sm
import pandas as pd
import os, sys

# %%
print('python version: ' + sys.version)
print('py_stringsimjoin version: ' + ssj.__version__)
print('py_stringmatching version: ' + sm.__version__)
print('pandas version: ' + pd.__version__)
# Out:
# python version: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# py_stringsimjoin version: 0.3.6
# py_stringmatching version: 0.4.6
# pandas version: 2.2.2

# %%
# Elon Musk appears twice due to SpaceX and Tesla
exec_df.drop_duplicates(inplace=True)

# %%
# Now let's do a similarity join

# We'll reset the index, so there is a unique index field in the company_ceos_df dataframe
company_ceos_df.reset_index(inplace=True)

output_pairs = ssj.jaccard_join(company_ceos_df, exec_df, 'index', 'page', 'Executive', 'clean_name', tok, 0.35,
                                l_out_attrs=['Executive'], r_out_attrs=['name'])

output_pairs[output_pairs['_sim_score'] < 1.0]
# Out:
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
#      _id  l_index                                            r_page  \
# 33    33       32         https://en.wikipedia.org/wiki/Jane_Fraser
# 38    38       38  https://en.wikipedia.org/wiki/Ola_K%C3%A4llenius
# 45    45       45   https://en.wikipedia.org/wiki/B%C3%B6rje_Ekholm
# 100  100      100   https://en.wikipedia.org/wiki/Michael_O%27Leary
#
#          l_Executive              r_name  _sim_score
# 33    Jane N. Fraser         Jane_Fraser    0.571429
# 38     Ola Källenius  Ola_K%C3%A4llenius    0.444444
# 45      Börje Ekholm   B%C3%B6rje_Ekholm    0.423077
# 100  Michael O'Leary   Michael_O%27Leary    0.538462

# %%
# At last! Company info + CEO info, together!

total = company_ceos_df.merge(output_pairs,left_on=['Executive'],right_on=['l_Executive']).\
        merge(exec_df,left_on=['r_page'],right_on=['page']).\
        merge(company_data_df, left_on='Company', right_on='name', how="left")

total
# Out:
#      index             Company             Executive  \
# 0        0           Accenture           Julie Sweet
# 1        1  Aditya Birla Group  Kumar Mangalam Birla
# 2        2       Adobe Systems      Shantanu Narayen
# 3        3              Airbus       Guillaume Faury
# 4        4             Alibaba              Eddie Wu
# ..     ...                 ...                   ...
# 137    135     Warner Brothers           Ann Sarnoff
# 138    136         WarnerMedia           Jason Kilar
# 139    137         Wells Fargo        Charles Scharf
# 140    138  Whole Foods Market           John Mackey
# 141    139        Zillow Group           Rich Barton
#
#                               Title    Since  \
# 0                            CEO[1]     2019
# 1                       Chairman[2]  1995[2]
# 2    Chairman, president and CEO[3]     2007
# 3                            CEO[4]     2012
# 4               Director and CEO[5]  2023[6]
# ..                              ...      ...
# 137         Chairwoman and CEO[123]     2019
# 138                        CEO[124]     2020
# 139          CEO and president[125]     2019
# 140                        CEO[126]     1980
# 141                        CEO[127]     2019
#
#                                                                                           Notes  \
# 0                                                               Succeeded Pierre Nanterme, died
# 1                                              Part of the Birla family business house in India
# 2                                                                           Formerly with Apple
# 3                                                                       Succeeded Louis Gallois
# 4                                                                                           NaN
# ..                                                                                          ...
# 137                  First woman to hold the position at the company; succeeded Kevin Tsujihara
# 138                                                             Previously with Hulu and Amazon
# 139                                                       Succeeded John Stumpf, previously COO
# 140                                                                                  Co-founder
# 141  Co-founder and previously was Zillow's CEO for nearly a decade. Succeeded Spencer Rascoff.
#
#         Updated  _id  l_index  \
# 0    2019-01-31    0        0
# 1    2018-10-01    1        1
# 2    2018-10-01    2        2
# 3    2017-11-14    3        3
# 4    2024-07-19    4        4
# ..          ...  ...      ...
# 137  2019-10-10  135      135
# 138  2020-11-19  136      136
# 139         NaN  137      137
# 140  2017-11-11  138      138
# 141  2018-12-10  139      139
#
#                                                  r_page  ... state_code  \
# 0             https://en.wikipedia.org/wiki/Julie_Sweet  ...        NaN
# 1    https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla  ...        NaN
# 2        https://en.wikipedia.org/wiki/Shantanu_Narayen  ...        NaN
# 3         https://en.wikipedia.org/wiki/Guillaume_Faury  ...        NaN
# 4                https://en.wikipedia.org/wiki/Eddie_Wu  ...        NaN
# ..                                                  ...  ...        ...
# 137           https://en.wikipedia.org/wiki/Ann_Sarnoff  ...        NaN
# 138           https://en.wikipedia.org/wiki/Jason_Kilar  ...        NaN
# 139        https://en.wikipedia.org/wiki/Charles_Scharf  ...        NaN
# 140           https://en.wikipedia.org/wiki/John_Mackey  ...        NaN
# 141           https://en.wikipedia.org/wiki/Rich_Barton  ...        NaN
#
#        region      city funding_rounds  founded_at founded_month  \
# 0         NaN       NaN            NaN         NaN           NaN
# 1         NaN       NaN            NaN         NaN           NaN
# 2         NaN       NaN            NaN         NaN           NaN
# 3         NaN       NaN            NaN         NaN           NaN
# 4    Hangzhou  Hangzhou            4.0  01/06/1999       1999-06
# ..        ...       ...            ...         ...           ...
# 137       NaN       NaN            NaN         NaN           NaN
# 138       NaN       NaN            NaN         NaN           NaN
# 139       NaN       NaN            NaN         NaN           NaN
# 140       NaN       NaN            NaN         NaN           NaN
# 141       NaN       NaN            NaN         NaN           NaN
#
#     founded_quarter founded_year first_funding_at last_funding_at
# 0               NaN          NaN              NaN             NaN
# 1               NaN          NaN              NaN             NaN
# 2               NaN          NaN              NaN             NaN
# 3               NaN          NaN              NaN             NaN
# 4           1999-Q2       1999.0       01/10/1999      11/08/2005
# ..              ...          ...              ...             ...
# 137             NaN          NaN              NaN             NaN
# 138             NaN          NaN              NaN             NaN
# 139             NaN          NaN              NaN             NaN
# 140             NaN          NaN              NaN             NaN
# 141             NaN          NaN              NaN             NaN
#
# [142 rows x 35 columns]

# %%
# Let's get ready to plot

# %matplotlib inline

# %%
total
# Out:
#      index             Company             Executive  \
# 0        0           Accenture           Julie Sweet
# 1        1  Aditya Birla Group  Kumar Mangalam Birla
# 2        2       Adobe Systems      Shantanu Narayen
# 3        3              Airbus       Guillaume Faury
# 4        4             Alibaba              Eddie Wu
# ..     ...                 ...                   ...
# 137    135     Warner Brothers           Ann Sarnoff
# 138    136         WarnerMedia           Jason Kilar
# 139    137         Wells Fargo        Charles Scharf
# 140    138  Whole Foods Market           John Mackey
# 141    139        Zillow Group           Rich Barton
#
#                               Title    Since  \
# 0                            CEO[1]     2019
# 1                       Chairman[2]  1995[2]
# 2    Chairman, president and CEO[3]     2007
# 3                            CEO[4]     2012
# 4               Director and CEO[5]  2023[6]
# ..                              ...      ...
# 137         Chairwoman and CEO[123]     2019
# 138                        CEO[124]     2020
# 139          CEO and president[125]     2019
# 140                        CEO[126]     1980
# 141                        CEO[127]     2019
#
#                                                                                           Notes  \
# 0                                                               Succeeded Pierre Nanterme, died
# 1                                              Part of the Birla family business house in India
# 2                                                                           Formerly with Apple
# 3                                                                       Succeeded Louis Gallois
# 4                                                                                           NaN
# ..                                                                                          ...
# 137                  First woman to hold the position at the company; succeeded Kevin Tsujihara
# 138                                                             Previously with Hulu and Amazon
# 139                                                       Succeeded John Stumpf, previously COO
# 140                                                                                  Co-founder
# 141  Co-founder and previously was Zillow's CEO for nearly a decade. Succeeded Spencer Rascoff.
#
#         Updated  _id  l_index  \
# 0    2019-01-31    0        0
# 1    2018-10-01    1        1
# 2    2018-10-01    2        2
# 3    2017-11-14    3        3
# 4    2024-07-19    4        4
# ..          ...  ...      ...
# 137  2019-10-10  135      135
# 138  2020-11-19  136      136
# 139         NaN  137      137
# 140  2017-11-11  138      138
# 141  2018-12-10  139      139
#
#                                                  r_page  ... state_code  \
# 0             https://en.wikipedia.org/wiki/Julie_Sweet  ...        NaN
# 1    https://en.wikipedia.org/wiki/Kumar_Mangalam_Birla  ...        NaN
# 2        https://en.wikipedia.org/wiki/Shantanu_Narayen  ...        NaN
# 3         https://en.wikipedia.org/wiki/Guillaume_Faury  ...        NaN
# 4                https://en.wikipedia.org/wiki/Eddie_Wu  ...        NaN
# ..                                                  ...  ...        ...
# 137           https://en.wikipedia.org/wiki/Ann_Sarnoff  ...        NaN
# 138           https://en.wikipedia.org/wiki/Jason_Kilar  ...        NaN
# 139        https://en.wikipedia.org/wiki/Charles_Scharf  ...        NaN
# 140           https://en.wikipedia.org/wiki/John_Mackey  ...        NaN
# 141           https://en.wikipedia.org/wiki/Rich_Barton  ...        NaN
#
#        region      city funding_rounds  founded_at founded_month  \
# 0         NaN       NaN            NaN         NaN           NaN
# 1         NaN       NaN            NaN         NaN           NaN
# 2         NaN       NaN            NaN         NaN           NaN
# 3         NaN       NaN            NaN         NaN           NaN
# 4    Hangzhou  Hangzhou            4.0  01/06/1999       1999-06
# ..        ...       ...            ...         ...           ...
# 137       NaN       NaN            NaN         NaN           NaN
# 138       NaN       NaN            NaN         NaN           NaN
# 139       NaN       NaN            NaN         NaN           NaN
# 140       NaN       NaN            NaN         NaN           NaN
# 141       NaN       NaN            NaN         NaN           NaN
#
#     founded_quarter founded_year first_funding_at last_funding_at
# 0               NaN          NaN              NaN             NaN
# 1               NaN          NaN              NaN             NaN
# 2               NaN          NaN              NaN             NaN
# 3               NaN          NaN              NaN             NaN
# 4           1999-Q2       1999.0       01/10/1999      11/08/2005
# ..              ...          ...              ...             ...
# 137             NaN          NaN              NaN             NaN
# 138             NaN          NaN              NaN             NaN
# 139             NaN          NaN              NaN             NaN
# 140             NaN          NaN              NaN             NaN
# 141             NaN          NaN              NaN             NaN
#
# [142 rows x 35 columns]

# %% [markdown]
# ## Simple Analysis of Linked Data: Grouping and Analytics
#
# The `groupby` command allows us to coalesce data by groups.  In Pandas a Group is a special object with a set of rows.  We can see this with the `get_group` command.

# %%
total[['born','Company','Executive']].sort_values('born')
# Out:
#                     born                     Company              Executive
# 63   1576-02-29 00:00:00  Hewlett Packard Enterprise           Antonio Neri
# 17   1930-08-30 00:00:00          Berkshire Hathaway         Warren Buffett
# 71   1935-11-01 00:00:00             Koch Industries        Charles G. Koch
# 135  1941-06-04 00:00:00    Walgreens Boots Alliance        Stefano Pessina
# 20   1947-02-14 00:00:00            Blackstone Group  Stephen A. Schwarzman
# ..                   ...                         ...                    ...
# 127                  NaT            UnitedHealthcare         Brian Thompson
# 131                  NaT                   Visa Inc.         Ryan McInerney
# 137                  NaT             Warner Brothers            Ann Sarnoff
# 140                  NaT          Whole Foods Market            John Mackey
# 141                  NaT                Zillow Group            Rich Barton
#
# [142 rows x 3 columns]

# %%
total.groupby(by='born').get_group(datetime.datetime.strptime('1935-11-01', '%Y-%m-%d'))[['Company','Executive','born']]
# Out:
#             Company        Executive                 born
# 71  Koch Industries  Charles G. Koch  1935-11-01 00:00:00

# %% [markdown]
# We can apply computations, such as `count`, to the items in the group.  Values that are empty (NaN) do not count (no pun intended).

# %%
total.groupby(by='born').count()
# Out:
#                      index  Company  Executive  Title  Since  Notes  Updated  \
# born
# 1576-02-29 00:00:00      1        1          1      1      1      1        1
# 1930-08-30 00:00:00      1        1          1      1      1      1        1
# 1935-11-01 00:00:00      1        1          1      1      1      1        1
# 1941-06-04 00:00:00      1        1          1      1      1      1        1
# 1947-02-14 00:00:00      1        1          1      1      1      1        1
# ...                    ...      ...        ...    ...    ...    ...      ...
# 1974-08-16 00:00:00      1        1          1      1      1      1        1
# 1976-01-22 00:00:00      1        1          1      1      1      1        1
# 1976-08-26 00:00:00      1        1          1      1      1      1        1
# 1980-05-04 00:00:00      1        1          1      1      1      1        1
# 1984-05-14 00:00:00      1        1          1      1      1      1        1
#
#                      _id  l_index  r_page  ...  state_code  region  city  \
# born                                       ...
# 1576-02-29 00:00:00    1        1       1  ...           0       0     0
# 1930-08-30 00:00:00    1        1       1  ...           0       0     0
# 1935-11-01 00:00:00    1        1       1  ...           0       0     0
# 1941-06-04 00:00:00    1        1       1  ...           0       0     0
# 1947-02-14 00:00:00    1        1       1  ...           0       0     0
# ...                  ...      ...     ...  ...         ...     ...   ...
# 1974-08-16 00:00:00    1        1       1  ...           1       1     1
# 1976-01-22 00:00:00    1        1       1  ...           0       0     0
# 1976-08-26 00:00:00    1        1       1  ...           0       0     0
# 1980-05-04 00:00:00    1        1       1  ...           0       0     0
# 1984-05-14 00:00:00    1        1       1  ...           1       1     1
#
#                      funding_rounds  founded_at  founded_month  \
# born
# 1576-02-29 00:00:00               0           0              0
# 1930-08-30 00:00:00               0           0              0
# 1935-11-01 00:00:00               0           0              0
# 1941-06-04 00:00:00               0           0              0
# 1947-02-14 00:00:00               0           0              0
# ...                             ...         ...            ...
# 1974-08-16 00:00:00               1           1              1
# 1976-01-22 00:00:00               0           0              0
# 1976-08-26 00:00:00               0           0              0
# 1980-05-04 00:00:00               0           0              0
# 1984-05-14 00:00:00               1           1              1
#
#                      founded_quarter  founded_year  first_funding_at  \
# born
# 1576-02-29 00:00:00                0             0                 0
# 1930-08-30 00:00:00                0             0                 0
# 1935-11-01 00:00:00                0             0                 0
# 1941-06-04 00:00:00                0             0                 0
# 1947-02-14 00:00:00                0             0                 0
# ...                              ...           ...               ...
# 1974-08-16 00:00:00                1             1                 1
# 1976-01-22 00:00:00                0             0                 0
# 1976-08-26 00:00:00                0             0                 0
# 1980-05-04 00:00:00                0             0                 0
# 1984-05-14 00:00:00                1             1                 1
#
#                      last_funding_at
# born
# 1576-02-29 00:00:00                0
# 1930-08-30 00:00:00                0
# 1935-11-01 00:00:00                0
# 1941-06-04 00:00:00                0
# 1947-02-14 00:00:00                0
# ...                              ...
# 1974-08-16 00:00:00                1
# 1976-01-22 00:00:00                0
# 1976-08-26 00:00:00                0
# 1980-05-04 00:00:00                0
# 1984-05-14 00:00:00                1
#
# [77 rows x 34 columns]

# %%
# We can do this in SQL too...

### Until pandas 0.15, there is a bug in converting datetimes to sqllite
### so we have to copy to a string instead
total2 = total.copy()
total2['born'] = total2['born'].apply(lambda x: str(x))

total2.to_sql('total_info', conn, if_exists='replace', index=False)

# By default, SQL will include the Nan value (called NULL in SQL).  If we want to exclude it,
# we need to include WHERE ... IS NOT NULL.

pd.read_sql('select born, count(Company) from total_info ' +\
            'where born is not null group by born', conn)
# Out:
#                    born  count(Company)
# 0   1576-02-29 00:00:00               1
# 1   1930-08-30 00:00:00               1
# 2   1935-11-01 00:00:00               1
# 3   1941-06-04 00:00:00               1
# 4   1947-02-14 00:00:00               1
# ..                  ...             ...
# 73  1976-01-22 00:00:00               1
# 74  1976-08-26 00:00:00               1
# 75  1980-05-04 00:00:00               1
# 76  1984-05-14 00:00:00               1
# 77                  NaT              62
#
# [78 rows x 2 columns]

# %%
total2 = total.dropna()
total2['born'] = total2['born'].astype('datetime64[ns]')
# Out:
# <ipython-input-55-45221ea3e444>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total2['born'] = total2['born'].astype('datetime64[ns]')

# %%
# Let's look at when the CEOs were born

birthdays = total2.groupby(by='born').count()[['Executive']]
birthdays.index = pd.to_datetime(birthdays.index, unit='s')

birthdays
# Out:
#             Executive
# born
# 1953-12-27          1
# 1959-06-28          1
# 1961-03-11          1
# 1965-06-23          1
# 1966-02-08          1
# 1968-01-13          1
# 1971-03-11          1
# 1972-06-10          1
# 1974-08-16          1
# 1984-05-14          1

# %% [markdown]
# We can actually use `resample` over dates, with a parameter, to group eg by decade (10 years, where A is the code for year):

# %%
birthdays.resample('10A').count().plot(kind='bar')
# Out:
# <ipython-input-57-f4df7082b500>:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   birthdays.resample('10A').count().plot(kind='bar')
# <Axes: xlabel='born'>

# %% [markdown]
# Maybe that's a little weird.  Can we do something more along the lines of what we expect, i.e., "1920s, 1930s, ..."?

# %%
# Get rid of the nulls!
bdays = total[['born']].dropna()

bdays = bdays.applymap(lambda bday: str(int(bday.year / 10) * 10) + 's')

bdays.reset_index().groupby('born').count().plot(kind='bar')
# Out:
# <ipython-input-58-9b886feb078d>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   bdays = bdays.applymap(lambda bday: str(int(bday.year / 10) * 10) + 's')
# <Axes: xlabel='born'>

# %% [markdown]
# # An Exercise
#
# Is there a correlation between the kind of company and the age of the CEO?
#
# Does the company's line of business matter?
